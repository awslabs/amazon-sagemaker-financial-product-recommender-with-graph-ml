# %% [markdown]
# # Parse raw CUSIP data

# %%
import pandas as pd
from tqdm import tqdm

def is_cusip(s):    
    q = s[:11]
    if len(q) < 11:
        return False
    if q[6] != ' ':
        return False
    if q[9] != ' ':
        return False    
    if not ('0' <= q[10] <= '9'):
        return False    
    nn = 0
    ns = 0
    for c in q:
        if '0' <= c <= '9':
            nn += 1
        elif 'A' <= c <= 'Z':
            pass
        elif c == ' ':
            ns += 1
        else:
            return False
    return nn > 2 and ns == 2

is_cusip('G02602 95 3'), is_cusip('STATUS'), is_cusip('4')
# Out:
# (True, False, False)

# %%
df = pd.read_csv('cusips_raw.tsv', sep='\t')
df
# Out:
#                            path  line_number  \
# 0        source_data/2004q1.pdf            1
# 1        source_data/2004q1.pdf            2
# 2        source_data/2004q1.pdf            3
# 3        source_data/2004q1.pdf            4
# 4        source_data/2004q1.pdf            5
# ...                         ...          ...
# 5209440  source_data/2017q4.pdf        93566
# 5209441  source_data/2017q4.pdf        93567
# 5209442  source_data/2017q4.pdf        93568
# 5209443  source_data/2017q4.pdf        93569
# 5209444  source_data/2017q4.pdf        93570
#
#                                                       line
# 0                          List of Section 13F Securities
# 1                                                      NaN
# 2                           1st Quarter (cid:139) FY 2004
# 3                                                      NaN
# 4        Copyright (c) 2004 American Bankers Associatio...
# ...                                                    ...
# 5209440                                                PUT
# 5209441                                                NaN
# 5209442                                Total Count: 17,770
# 5209443                                                NaN
# 5209444
#
#
# [5209445 rows x 3 columns]

# %%
useless = {'', '*', 'IVM001', 'ISSUER NAME', 'ISSUER DESCRIPTION', 'STATUS'}
lines = [li.strip() for li in df.dropna().line.to_list()]
lines = [li for li in lines if li not in useless]
lines
# Out:
# ['List of Section 13F Securities',
#  '1st Quarter (cid:139) FY 2004',
#  'Copyright (c) 2004 American Bankers Association. CUSIP Numbers and',
#  'descriptions are used with permission by Standard & Poors CUSIP Service',
#  'Bureau, a division of The McGraw-Hill Companies, Inc.  All rights reserved.',
#  'No redistribution without permission from Standard & Poors CUSIP Service',
#  'Bureau.',
#  'Standard & Poors CUSIP Service Bureau does not guarantee the accuracy',
#  'or completeness of the CUSIP Numbers and standard descriptions included',
#  'herein and neither the American Bankers Association nor Standard &',
#  "Poor's CUSIP Service Bureau shall be responsible for any errors, omissions",
#  'or damages arising out of the use of such information.',
#  'U.S. Securities and Exchange Commission',
#  'OFFICIAL LIST OF SECTION 13(f) SECURITIES USER INFORMATION SHEET',
#  'General',
#  'This list of “Section 13(f) securities” as defined by Rule',
#  '13f-1(c)  [17 CFR 240.13f-1(c)] is made available to the public',
#  'pursuant to Section13 (f) (3) of the Securities Exchange Act of 1934',
#  '[15 USC 78m(f) (3)].  It is made available for use in the preparation of reports',
#  'filed with the Securities and Exhange Commission pursuant to Rule 13f-1 [17',
#  'CFR 240.13f-1] under Section 13(f) of the Securities Exchange Act of 1934. An',
#  'updated list is published on a quarterly basis.',
#  'This list is current as of  March 15, 2004, and may be relied on by',
#  'institutional investment managers filing Form 13F reports for the calendar quarter',
#  'ending March 31, 2004. Institutional investment managers should report',
#  'holdings--number of shares and fair market value--as of the last day of the',
#  'calendar quarter as required by Section 13(f)(1) and Rule 13f-1 thereunder.',
#  'Features',
#  '(1)',
#  'Additions and Deletions: Revisions made to the list of Section 13(f)',
#  'securities are indicated in a column titled “STATUS.”  The word',
#  '“ADDED” in the status column opposite the name of a security',
#  'indicates that the security has become a Section 13(f) security.',
#  'The word “DELETED” in the status column opposite the name of a',
#  'security indicates that the security ceases to be a 13(f) security',
#  'since the date of the last list.',
#  '(2)',
#  'List of options: An asterisk is placed next to the name of any',
#  'security having a listed option and each option is individually listed',
#  'with its own CUSIP number immediately below the name of the',
#  'security having the option. A manager reporting holdings of options',
#  'on its Form13F should use the CUSIP number of each option as to',
#  'which holding are reported.',
#  'Run Date:',
#  '3/31/2004',
#  '** List Of Section 13F Securities **',
#  'Run Time:',
#  '14:38',
#  'Fiscal Year: 2004  Qtr: 1',
#  'Page',
#  '1',
#  'CUSIP NO',
#  'B49233 10 7',
#  'ICOS VISION SYS CORP N V',
#  'D1497A 10 1',
#  'CELANESE AG',
#  'D1668R 12 3',
#  'DAIMLERCHRYSLER AG',
#  'D1668R 90 3',
#  'DAIMLERCHRYSLER AG',
#  'D1668R 95 3',
#  'DAIMLERCHRYSLER AG',
#  'ORD',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'D18190 89 8',
#  'DEUTSCHE BANK AG NAMEN',
#  'ORD',
#  'D18190 90 8',
#  'DEUTSCHE BANK AG NAMEN',
#  'D18190 95 8',
#  'DEUTSCHE BANK AG NAMEN',
#  'CALL',
#  'PUT',
#  'G0070K 10 3',
#  'ACE LTD',
#  'ORD',
#  'G0070K 90 3',
#  'ACE LTD',
#  'G0070K 95 3',
#  'ACE LTD',
#  'CALL',
#  'PUT',
#  'G02602 10 3',
#  'AMDOCS LTD',
#  'ORD',
#  'G02602 90 3',
#  'AMDOCS LTD',
#  'G02602 95 3',
#  'AMDOCS LTD',
#  'G02995 10 1',
#  'AMERICAN SAFETY INS HLDGS LT',
#  'G03910 10 9',
#  'ANNUITY AND LIFE RE HLDGS',
#  'G03910 90 9',
#  'ANNUITY AND LIFE RE HLDGS',
#  'G03910 95 9',
#  'ANNUITY AND LIFE RE HLDGS',
#  'CALL',
#  'PUT',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'G04074 10 3',
#  'APEX SILVER MINES LTD',
#  'ORD',
#  'G04074 90 3',
#  'APEX SILVER MINES LTD',
#  'G04074 95 3',
#  'APEX SILVER MINES LTD',
#  'CALL',
#  'PUT',
#  'G0450A 10 5',
#  'ARCH CAP GROUP LTD',
#  'ORD',
#  'G0450A 90 5',
#  'ARCH CAP GROUP LTD',
#  'G0450A 95 5',
#  'ARCH CAP GROUP LTD',
#  'G05384 10 5',
#  'ASPEN INSURANCE HOLDINGS LTD',
#  'G0692U 10 9',
#  'AXIS CAPITAL HOLDINGS',
#  'CALL',
#  'PUT',
#  'SHS',
#  'SHS',
#  'G07644 10 0',
#  'BANK OF BERMUDA LTD',
#  'SHS',
#  'DELETED',
#  'G1150G 11 1',
#  'ACCENTURE LTD BERMUDA',
#  'CL A',
#  'G1150G 90 1',
#  'ACCENTURE LTD BERMUDA',
#  'G1150G 95 1',
#  'ACCENTURE LTD BERMUDA',
#  'CALL',
#  'PUT',
#  'G16962 10 5',
#  'BUNGE LIMITED',
#  'COM',
#  'G16962 90 5',
#  'BUNGE LIMITED',
#  'G16962 95 5',
#  'BUNGE LIMITED',
#  'CALL',
#  'PUT',
#  'G20045 20 2',
#  'CENTRAL EUROPEAN MEDIA ENTRP',
#  'CL A NEW',
#  'Run Date:',
#  '3/31/2004',
#  '** List Of Section 13F Securities **',
#  'Run Time:',
#  '14:38',
#  'Fiscal Year: 2004  Qtr: 1',
#  'Page',
#  '2',
#  'CUSIP NO',
#  'G2108N 10 9',
#  'CHINADOTCOM CORP',
#  'CL A',
#  'G2108N 90 9',
#  'CHINADOTCOM CORP',
#  'G2108N 95 9',
#  'CHINADOTCOM CORP',
#  'CALL',
#  'PUT',
#  'G21082 10 5',
#  'CHINA YUCHAI INTL LTD',
#  'COM',
#  'G21082 90 5',
#  'CHINA YUCHAI INTL LTD',
#  'G21082 95 5',
#  'CHINA YUCHAI INTL LTD',
#  'CALL',
#  'PUT',
#  'G2110R 10 6',
#  'CHIPMOS TECH BERMUDA LTD',
#  'SHS',
#  'G2110R 90 6',
#  'CHIPMOS TECH BERMUDA LTD',
#  'G2110R 95 6',
#  'CHIPMOS TECH BERMUDA LTD',
#  'G23773 10 7',
#  'CONSOLIDATED WATER CO INC',
#  'G24182 10 0',
#  'COOPER INDS LTD',
#  'G24182 90 0',
#  'COOPER INDS LTD',
#  'G24182 95 0',
#  'COOPER INDS LTD',
#  'G2519Y 10 8',
#  'CREDICORP LTD',
#  'G27545 10 5',
#  'DF CHINA TECHNOLOGY INC',
#  'G28471 10 3',
#  'DSG INTL LTD',
#  'CALL',
#  'PUT',
#  'ORD',
#  'CL A',
#  'CALL',
#  'PUT',
#  'COM',
#  'ORD',
#  'ORD',
#  'G29539 16 3',
#  'ELAN CORP PLC',
#  '*W EXP 08/31/200',
#  'G30397 10 6',
#  'ENDURANCE SPECIALTY HLDGS LT',
#  'G31611 10 9',
#  'XCELERA INC',
#  'G31611 90 9',
#  'XCELERA INC',
#  'G31611 95 9',
#  'XCELERA INC',
#  'G32030 10 1',
#  'EURO TECH HOLDINGS CO LTD',
#  'G3223R 10 8',
#  'EVEREST RE GROUP LTD',
#  'G3223R 90 8',
#  'EVEREST RE GROUP LTD',
#  'G3223R 95 8',
#  'EVEREST RE GROUP LTD',
#  'SHS',
#  'COM',
#  'CALL',
#  'PUT',
#  'ORD',
#  'COM',
#  'CALL',
#  'PUT',
#  'G36738 10 5',
#  'FRESH DEL MONTE PRODUCE INC',
#  'ORD',
#  'G36738 90 5',
#  'FRESH DEL MONTE PRODUCE INC',
#  'G36738 95 5',
#  'FRESH DEL MONTE PRODUCE INC',
#  'G3682E 12 7',
#  'FRONTLINE LTD',
#  'G37260 10 9',
#  'GARMIN LTD',
#  'G37260 90 9',
#  'GARMIN LTD',
#  'G37260 95 9',
#  'GARMIN LTD',
#  'CALL',
#  'PUT',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'G3921A 17 5',
#  'GLOBAL CROSSING LTD',
#  'SHS NEW',
#  'G3921A 90 5',
#  'GLOBAL CROSSING LTD',
#  'CALL',
#  'ADDED',
#  'ADDED',
#  'Run Date:',
#  '3/31/2004',
#  '** List Of Section 13F Securities **',
#  'Run Time:',
#  '14:38',
#  'Fiscal Year: 2004  Qtr: 1',
#  'CUSIP NO',
#  'G3921A 95 5',
#  'GLOBAL CROSSING LTD',
#  'PUT',
#  'G3930E 10 1',
#  'GLOBALSANTAFE CORP',
#  'SHS',
#  'Page',
#  '3',
#  'ADDED',
#  'G3930E 90 1',
#  'GLOBALSANTAFE CORP',
#  'G3930E 95 1',
#  'GLOBALSANTAFE CORP',
#  'G39300 10 1',
#  'GLOBAL SOURCES LTD',
#  'G39320 10 9',
#  'GLOBAL-TECH APPLIANCES INC',
#  'G4388N 10 6',
#  'HELEN OF TROY CORP LTD',
#  'G4388N 90 6',
#  'HELEN OF TROY CORP LTD',
#  'G4388N 95 6',
#  'HELEN OF TROY CORP LTD',
#  'G4481U 10 6',
#  'HIGHWAY HLDGS LTD',
#  'G4776G 10 1',
#  'INGERSOLL-RAND COMPANY LTD',
#  'G4776G 90 1',
#  'INGERSOLL-RAND COMPANY LTD',
#  'G4776G 95 1',
#  'INGERSOLL-RAND COMPANY LTD',
#  'CALL',
#  'PUT',
#  'ORD',
#  'ORD',
#  'COM',
#  'CALL',
#  'PUT',
#  'ORD',
#  'CL A',
#  'CALL',
#  'PUT',
#  'G4911N 30 0',
#  'INTERWAVE COMMUNCTNS INTL LT',
#  'SHS NEW',
#  'G4933P 10 1',
#  'IPC HLDGS LTD',
#  'ORD',
#  'G4933P 90 1',
#  'IPC HLDGS LTD',
#  'G4933P 95 1',
#  'IPC HLDGS LTD',
#  'G5138L 10 0',
#  'JINPAN INTL LTD',
#  'G5299G 10 6',
#  'KNIGHTSBRIDGE TANKERS LTD',
#  'G55312 10 5',
#  'LJ INTL INC',
#  'CALL',
#  'PUT',
#  'ORD',
#  'ORD',
#  'ORD',
#  'G55312 11 3',
#  'LJ INTL INC',
#  '*W EXP 04/15/200',
#  'G5876H 10 5',
#  'MARVELL TECHNOLOGY GROUP LTD',
#  'ORD',
#  'G5876H 90 5',
#  'MARVELL TECHNOLOGY GROUP LTD',
#  'G5876H 95 5',
#  'MARVELL TECHNOLOGY GROUP LTD',
#  'CALL',
#  'PUT',
#  'G6052F 10 3',
#  'MAX RE CAPITAL LTD HAMILTON',
#  'SHS',
#  'G6052F 90 3',
#  'MAX RE CAPITAL LTD HAMILTON',
#  'G6052F 95 3',
#  'MAX RE CAPITAL LTD HAMILTON',
#  'G62185 10 6',
#  'MONTPELIER RE HOLDINGS LTD',
#  'G6359F 10 3',
#  'NABORS INDUSTRIES LTD',
#  'G6359F 90 3',
#  'NABORS INDUSTRIES LTD',
#  'G6359F 95 3',
#  'NABORS INDUSTRIES LTD',
#  'CALL',
#  'PUT',
#  'SHS',
#  'SHS',
#  'CALL',
#  'PUT',
#  'G65422 10 0',
#  'NOBLE CORPORATION',
#  'SHS',
#  'G65422 90 0',
#  'NOBLE CORPORATION',
#  'G65422 95 0',
#  'NOBLE CORPORATION',
#  'CALL',
#  'PUT',
#  'Run Date:',
#  '3/31/2004',
#  '** List Of Section 13F Securities **',
#  'Run Time:',
#  '14:38',
#  'Fiscal Year: 2004  Qtr: 1',
#  'Page',
#  '4',
#  'CUSIP NO',
#  'G65773 10 6',
#  'NORDIC AMERICAN TANKER SHIPP',
#  'G6674P 10 9',
#  'NOVEL DENIM HLDGS LTD',
#  'G67543 10 1',
#  'OPENTV CORP',
#  'G67543 90 1',
#  'OPENTV CORP',
#  'G67543 95 1',
#  'OPENTV CORP',
#  'G67743 10 7',
#  'ORIENT-EXPRESS HOTELS LTD',
#  'G6797E 10 6',
#  'O2MICRO INTERNATIONAL LIMITE',
#  'G6797E 90 6',
#  'O2MICRO INTERNATIONAL LIMITE',
#  'G6797E 95 6',
#  'O2MICRO INTERNATIONAL LIMITE',
#  'COM',
#  'ORD',
#  'CL A',
#  'CALL',
#  'PUT',
#  'CL A',
#  'ORD',
#  'CALL',
#  'PUT',
#  'G6852T 10 5',
#  'PARTNERRE LTD',
#  'COM',
#  'G6852T 90 5',
#  'PARTNERRE LTD',
#  'G6852T 95 5',
#  'PARTNERRE LTD',
#  'G69586 10 8',
#  'PEAK INTL LTD',
#  'G7127P 10 0',
#  'PLATINUM UNDERWRITER HLDGS L',
#  'CALL',
#  'PUT',
#  'ORD',
#  'COM',
#  'G7127P 90 0',
#  'PLATINUM UNDERWRITER HLDGS L',
#  'G7127P 95 0',
#  'PLATINUM UNDERWRITER HLDGS L',
#  'CALL',
#  'PUT',
#  'G73018 10 6',
#  'PXRE GROUP LTD',
#  'G7303A 10 9',
#  'QIAO XING UNIVERSAL TELEPHON',
#  'G7303A 90 9',
#  'QIAO XING UNIVERSAL TELEPHON',
#  'G7303A 95 9',
#  'QIAO XING UNIVERSAL TELEPHON',
#  'COM',
#  'ORD',
#  'CALL',
#  'PUT',
#  'G7342H 10 7',
#  'RADICA GAMES LTD',
#  'ORD',
#  'G7342H 90 7',
#  'RADICA GAMES LTD',
#  'G7342H 95 7',
#  'RADICA GAMES LTD',
#  'CALL',
#  'PUT',
#  'G7496G 10 3',
#  'RENAISSANCE RE HLDGS LTD',
#  'COM',
#  'G7496G 90 3',
#  'RENAISSANCE RE HLDGS LTD',
#  'G7496G 95 3',
#  'RENAISSANCE RE HLDGS LTD',
#  'G7885T 10 4',
#  'SCOTTISH RE GROUP LTD',
#  'G7945J 10 4',
#  'SEAGATE TECHNOLOGY',
#  'G7945J 90 4',
#  'SEAGATE TECHNOLOGY',
#  'G7945J 95 4',
#  'SEAGATE TECHNOLOGY',
#  'G81365 10 1',
#  'SILVERSTAR HLDGS LTD',
#  'G81477 10 4',
#  'SINA CORP',
#  'G81477 90 4',
#  'SINA CORP',
#  'G81477 95 4',
#  'SINA CORP',
#  'CALL',
#  'PUT',
#  'ORD',
#  'SHS',
#  'CALL',
#  'PUT',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'Run Date:',
#  '3/31/2004',
#  '** List Of Section 13F Securities **',
#  'Run Time:',
#  '14:38',
#  'Fiscal Year: 2004  Qtr: 1',
#  'Page',
#  '5',
#  'CUSIP NO',
#  'G84922 10 6',
#  'STEWART W P & CO LTD',
#  'G87210 10 3',
#  'UTI WORLDWIDE INC',
#  'COM',
#  'ORD',
#  'G88653 12 9',
#  'TIERS PRINCIPAL PROTECTED TR',
#  'S&P 01-19 TR',
#  'G88653 20 2',
#  'TIERS PRINCIPAL PROTECTED TR',
#  'G88653 40 0',
#  'TIERS PRINCIPAL PROTECTED TR',
#  'G88653 50 9',
#  'TIERS PRINCIPAL PROTECTED TR',
#  'G88653 60 8',
#  'TIERS PRINCIPAL PROTECTED TR',
#  'G88653 70 7',
#  'TIERS PRINCIPAL PROTECTED TR',
#  'G88653 80 6',
#  'TIERS PRINCIPAL PROTECTED TR',
#  'G88653 88 9',
#  'TIERS PRINCIPAL PROTECTED TR',
#  'G8915Z 10 2',
#  'HILFIGER TOMMY CORP',
#  'G8915Z 90 2',
#  'HILFIGER TOMMY CORP',
#  'G8915Z 95 2',
#  'HILFIGER TOMMY CORP',
#  'G89935 10 3',
#  'TRAMFORD INTL LTD',
#  'G90078 10 9',
#  'TRANSOCEAN INC',
#  'G90078 90 9',
#  'TRANSOCEAN INC',
#  'G90078 95 9',
#  'TRANSOCEAN INC',
#  'G9108L 10 8',
#  'TSAKOS ENERGY NAVIGATION LTD',
#  'G9456A 10 0',
#  'GOLAR LNG LTD BERMUDA',
#  'TIERS2000-2007',
#  'TIERS2000-2014',
#  'TIERS 2000-2013',
#  'S&P 2001 11 TR',
#  'TIERS 2001-13',
#  'DJIA 2001-26',
#  '2002-1 TR CTF',
#  'ORD',
#  'CALL',
#  'PUT',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'SHS',
#  'SHS',
#  'G95089 10 1',
#  'WEATHERFORD INTERNATIONAL LT',
#  'COM',
#  'G95089 90 1',
#  'WEATHERFORD INTERNATIONAL LT',
#  'G95089 95 1',
#  'WEATHERFORD INTERNATIONAL LT',
#  'CALL',
#  'PUT',
#  'G9618E 10 7',
#  'WHITE MTNS INS GROUP LTD',
#  'G96655 10 8',
#  'WILLIS GROUP HOLDINGS LTD',
#  'G96655 90 8',
#  'WILLIS GROUP HOLDINGS LTD',
#  'G96655 95 8',
#  'WILLIS GROUP HOLDINGS LTD',
#  'COM',
#  'SHS',
#  'CALL',
#  'PUT',
#  'G9825R 10 7',
#  'XOMA LTD',
#  'ORD',
#  'G9825R 90 7',
#  'XOMA LTD',
#  'G9825R 95 7',
#  'XOMA LTD',
#  'CALL',
#  'PUT',
#  'G98255 10 5',
#  'XL CAP LTD',
#  'CL A',
#  'G98255 90 5',
#  'XL CAP LTD',
#  'G98255 95 5',
#  'XL CAP LTD',
#  'CALL',
#  'PUT',
#  'H01301 10 2',
#  'ALCON INC',
#  'COM SHS',
#  'H01301 90 2',
#  'ALCON INC',
#  'CALL',
#  'Run Date:',
#  '3/31/2004',
#  '** List Of Section 13F Securities **',
#  'Run Time:',
#  '14:38',
#  'Fiscal Year: 2004  Qtr: 1',
#  'Page',
#  '6',
#  'CUSIP NO',
#  'H01301 95 2',
#  'ALCON INC',
#  'PUT',
#  'H8920M 85 5',
#  'UBS AG',
#  'NAMEN AKT',
#  'H8920M 90 5',
#  'UBS AG',
#  'H8920M 95 5',
#  'UBS AG',
#  'L20708 10 0',
#  'CRONOS GROUP S A',
#  'L63631 10 2',
#  'METRO INTERNATIONAL S A',
#  'L63631 11 0',
#  'METRO INTERNATIONAL S A',
#  'CALL',
#  'PUT',
#  'SHS',
#  'CL A',
#  'CL B',
#  'DELETED',
#  'DELETED',
#  'L6388F 11 0',
#  'MILLICOM INTL CELLULAR S A',
#  'SHS NEW',
#  'L6388F 90 0',
#  'MILLICOM INTL CELLULAR S A',
#  'L6388F 95 0',
#  'MILLICOM INTL CELLULAR S A',
#  'L8137F 10 2',
#  'SBS BROADCASTING SA',
#  'M01773 10 6',
#  'ACS TECH 80 LTD',
#  'M0392N 10 1',
#  'ALADDIN KNOWLEDGE SYS LTD',
#  'M0861T 10 0',
#  'ALVARION LTD',
#  'M0861T 90 0',
#  'ALVARION LTD',
#  'M0861T 95 0',
#  'ALVARION LTD',
#  'CALL',
#  'PUT',
#  'ORD',
#  'SHS',
#  'ORD',
#  'SHS',
#  'CALL',
#  'PUT',
#  'M14925 10 7',
#  'AREL COMMUNICATIONS & SOFTWA',
#  'COM',
#  'M15332 10 5',
#  'ATTUNITY LTD',
#  'M15342 10 4',
#  'AUDIOCODES LTD',
#  'M15342 90 4',
#  'AUDIOCODES LTD',
#  'M15342 95 4',
#  'AUDIOCODES LTD',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'M15633 10 6',
#  'BACKWEB TECHNOLOGIES LTD',
#  'ORD',
#  'M15633 90 6',
#  'BACKWEB TECHNOLOGIES LTD',
#  'M15633 95 6',
#  'BACKWEB TECHNOLOGIES LTD',
#  'CALL',
#  'PUT',
#  'M18955 10 0',
#  'BARAN GROUP LTD',
#  'NIS ORD SHS',
#  'M20115 13 1',
#  'BOS BETTER ONLINE SOLUTIONS',
#  'SHS NEW',
#  'M20157 10 9',
#  'BLUEPHOENIX SOLUTIONS LTD',
#  'M20330 10 2',
#  'ROBO GROUP TEK LTD',
#  'M20791 10 5',
#  'CAMTEK LTD',
#  'M22013 10 2',
#  'CERAGON NETWORKS LTD',
#  'M22013 90 2',
#  'CERAGON NETWORKS LTD',
#  'M22013 95 2',
#  'CERAGON NETWORKS LTD',
#  'SHS',
#  'SHS',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'M22465 10 4',
#  'CHECK POINT SOFTWARE TECH LT',
#  'ORD',
#  'M22465 90 4',
#  'CHECK POINT SOFTWARE TECH LT',
#  'CALL',
#  'Run Date:',
#  '3/31/2004',
#  '** List Of Section 13F Securities **',
#  'Run Time:',
#  '14:38',
#  'Fiscal Year: 2004  Qtr: 1',
#  'Page',
#  '7',
#  'CUSIP NO',
#  'M22465 95 4',
#  'CHECK POINT SOFTWARE TECH LT',
#  'PUT',
#  'M23798 10 7',
#  'CIMATRON LTD',
#  'M25082 10 4',
#  'CLICKSOFTWARE TECHNOLOGIES L',
#  'M25596 10 3',
#  'COMMTOUCH SOFTWARE LTD',
#  'M25596 90 3',
#  'COMMTOUCH SOFTWARE LTD',
#  'M25596 95 3',
#  'COMMTOUCH SOFTWARE LTD',
#  'M25722 10 5',
#  'COMPUGEN LTD',
#  'M29925 10 0',
#  'ECTEL LTD',
#  'M3760D 10 1',
#  'ELBIT SYS LTD',
#  'M3760D 90 1',
#  'ELBIT SYS LTD',
#  'M3760D 95 1',
#  'ELBIT SYS LTD',
#  'M37605 10 8',
#  'ELBIT MEDICAL IMAGING LTD',
#  'M40168 10 2',
#  'ELSCINT LTD NEW',
#  'M40184 10 9',
#  'ELTEK LTD',
#  'M47095 10 0',
#  'FUNDTECH LTD',
#  'M47095 90 0',
#  'FUNDTECH LTD',
#  'M47095 95 0',
#  'FUNDTECH LTD',
#  'M51474 11 8',
#  'GILAT SATELLITE NETWORKS LTD',
#  'M52020 10 0',
#  'GIVEN IMAGING',
#  'M52020 90 0',
#  'GIVEN IMAGING',
#  'M52020 95 0',
#  'GIVEN IMAGING',
#  'M52523 10 3',
#  'WILLI G FOOD INTL LTD',
#  'M5296L 13 5',
#  'HEALTHCARE TECHNOLOGIES LTD',
#  'M56595 10 7',
#  'INTERNET GOLD-GOLDEN LINES L',
#  'M6184R 10 1',
#  'JACADA LTD',
#  'M6706C 10 3',
#  'LANOPTICS LTD',
#  'M6772H 10 1',
#  'LIPMAN ELECTRONIC ENGINEERIN',
#  'M6778Q 10 5',
#  'LUMENIS LTD',
#  'M6778Q 90 5',
#  'LUMENIS LTD',
#  'M6778Q 95 5',
#  'LUMENIS LTD',
#  'ORD',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'ORD',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'ORD',
#  'ORD',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'SHS NEW',
#  'ORD SHS',
#  'CALL',
#  'PUT',
#  'ORD',
#  'COM',
#  'ORD',
#  'ORD',
#  'ORD',
#  'ORD',
#  'SHS',
#  'CALL',
#  'PUT',
#  'M6786D 10 4',
#  'MAGAL SECURITY SYS LTD',
#  'ORD',
#  'M69676 10 0',
#  'MER TELEMANAGEMENT SOLUTIONS',
#  'ORD',
#  'M69897 10 2',
#  'METALINK LTD',
#  'M69897 90 2',
#  'METALINK LTD',
#  'ORD',
#  'CALL',
#  'ADDED',
#  'DELETED',
#  'DELETED',
#  'DELETED',
#  'Run Date:',
#  '3/31/2004',
#  '** List Of Section 13F Securities **',
#  'Run Time:',
#  '14:38',
#  'Fiscal Year: 2004  Qtr: 1',
#  'Page',
#  '8',
#  'CUSIP NO',
#  'M69897 95 2',
#  'METALINK LTD',
#  'M70240 10 2',
#  'MIND C T I LTD',
#  'M7061C 10 0',
#  'M SYS FLASH DISK PIONEERS LT',
#  'M7061C 90 0',
#  'M SYS FLASH DISK PIONEERS LT',
#  'M7061C 95 0',
#  'M SYS FLASH DISK PIONEERS LT',
#  'PUT',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'M7516K 10 3',
#  'NOVA MEASURING INSTRUMENTS L',
#  'COM',
#  'M75165 10 6',
#  'NUR MACROPRINTERS LTD',
#  'M7524R 10 8',
#  'OPTIBASE LTD',
#  'M75253 10 0',
#  'ORBOTECH LTD',
#  'M75253 90 0',
#  'ORBOTECH LTD',
#  'M75253 95 0',
#  'ORBOTECH LTD',
#  'M7531S 20 6',
#  'ORCKIT COMMUNICATIONS LTD',
#  'M81863 10 8',
#  'RADA ELECTR INDS LTD',
#  'M81865 10 3',
#  'RADCOM LTD',
#  'M81867 10 9',
#  'RADVIEW SOFTWARE LTD',
#  'M81869 10 5',
#  'RADVISION LTD',
#  'M81869 90 5',
#  'RADVISION LTD',
#  'M81869 95 5',
#  'RADVISION LTD',
#  'ORD',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'SHS NEW',
#  'SHS NEW',
#  'ORD',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'M81873 10 7',
#  'RADWARE LTD',
#  'ORD',
#  'M81873 90 7',
#  'RADWARE LTD',
#  'M81873 95 7',
#  'RADWARE LTD',
#  'M8215N 10 9',
#  'RIT TECHNOLOGIES LTD',
#  'M8215W 10 9',
#  'RETALIX LTD',
#  'M84116 10 8',
#  'SILICOM LTD',
#  'M8737E 10 8',
#  'TARO PHARMACEUTICAL INDS LTD',
#  'M8737E 90 8',
#  'TARO PHARMACEUTICAL INDS LTD',
#  'M8737E 95 8',
#  'TARO PHARMACEUTICAL INDS LTD',
#  'CALL',
#  'PUT',
#  'ORD',
#  'ORD',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'M8740S 22 7',
#  'TAT TECHNOLOGIES LTD',
#  'ORD NEW',
#  'M8743P 10 5',
#  'TECNOMATIX TECHNOLOGIES LTD',
#  'ORD',
#  'M8743P 90 5',
#  'TECNOMATIX TECHNOLOGIES LTD',
#  'M8743P 95 5',
#  'TECNOMATIX TECHNOLOGIES LTD',
#  'M87482 10 1',
#  'TEFRON LTD',
#  'M87896 10 2',
#  'TOP IMAGE SYSTEMS LTD',
#  'M8791A 10 9',
#  'ON TRACK INNOVATION LTD',
#  'CALL',
#  'PUT',
#  'ORD',
#  'ORD',
#  'SHS',
#  'Run Date:',
#  '3/31/2004',
#  '** List Of Section 13F Securities **',
#  'Run Time:',
#  '14:38',
#  'Fiscal Year: 2004  Qtr: 1',
#  'Page',
#  '9',
#  'CUSIP NO',
#  'M87915 10 0',
#  'TOWER SEMICONDUCTOR LTD',
#  'ORD',
#  'M87915 90 0',
#  'TOWER SEMICONDUCTOR LTD',
#  'M87915 95 0',
#  'TOWER SEMICONDUCTOR LTD',
#  'CALL',
#  'PUT',
#  'M87915 13 4',
#  'TOWER SEMICONDUCTOR LTD',
#  '*W EXP 10/31/200',
#  'M88258 10 4',
#  'TTI TEAM TELECOM INTL LTD',
#  'M97385 11 2',
#  'VERISITY LTD',
#  'M97385 90 2',
#  'VERISITY LTD',
#  'M97385 95 2',
#  'VERISITY LTD',
#  'M97540 11 2',
#  'VIRYANET LTD',
#  'M97601 10 4',
#  'VOCALTEC COMMUNICATIONS LTD',
#  'N07045 10 2',
#  'ASM INTL N V',
#  'N07045 90 2',
#  'ASM INTL N V',
#  'N07045 95 2',
#  'ASM INTL N V',
#  'ORD',
#  'ORD',
#  'CALL',
#  'PUT',
#  'SHS NEW',
#  'ORD',
#  'COM',
#  'CALL',
#  'PUT',
#  'N07059 11 1',
#  'ASML HLDG NV',
#  'N Y SHS',
#  'N07059 90 1',
#  'ASML HLDG NV',
#  'N07059 95 1',
#  'ASML HLDG NV',
#  'CALL',
#  'PUT',
#  'N20935 20 6',
#  'CNH GLOBAL N V',
#  ...]

# %%
cusips = []
cusip = []
record = False

def add_cusip_to_list():
    if cusip:
        cusips.append(cusip)
    
for li in tqdm(lines):
    isc = is_cusip(li)
    if isc:
        add_cusip_to_list()
        if len(li) == 11:
            cusip = [li]
        else:
            cusip = [li[:11], li[11:]]
        record = True
    elif record:
        if li == 'Run Date:':
            record = False
        else:
            if li not in set(cusip):
                cusip.append(li)

add_cusip_to_list()
cusips
# Out:
# 100%|██████████| 2409393/2409393 [00:04<00:00, 505842.15it/s]
# [['B49233 10 7', 'ICOS VISION SYS CORP N V'],
#  ['D1497A 10 1', 'CELANESE AG'],
#  ['D1668R 12 3', 'DAIMLERCHRYSLER AG'],
#  ['D1668R 90 3', 'DAIMLERCHRYSLER AG'],
#  ['D1668R 95 3', 'DAIMLERCHRYSLER AG', 'ORD', 'CALL', 'PUT'],
#  ['D18190 89 8', 'DEUTSCHE BANK AG NAMEN', 'ORD'],
#  ['D18190 90 8', 'DEUTSCHE BANK AG NAMEN'],
#  ['D18190 95 8', 'DEUTSCHE BANK AG NAMEN', 'CALL', 'PUT'],
#  ['G0070K 10 3', 'ACE LTD', 'ORD'],
#  ['G0070K 90 3', 'ACE LTD'],
#  ['G0070K 95 3', 'ACE LTD', 'CALL', 'PUT'],
#  ['G02602 10 3', 'AMDOCS LTD', 'ORD'],
#  ['G02602 90 3', 'AMDOCS LTD'],
#  ['G02602 95 3', 'AMDOCS LTD'],
#  ['G02995 10 1', 'AMERICAN SAFETY INS HLDGS LT'],
#  ['G03910 10 9', 'ANNUITY AND LIFE RE HLDGS'],
#  ['G03910 90 9', 'ANNUITY AND LIFE RE HLDGS'],
#  ['G03910 95 9', 'ANNUITY AND LIFE RE HLDGS', 'CALL', 'PUT', 'ORD'],
#  ['G04074 10 3', 'APEX SILVER MINES LTD', 'ORD'],
#  ['G04074 90 3', 'APEX SILVER MINES LTD'],
#  ['G04074 95 3', 'APEX SILVER MINES LTD', 'CALL', 'PUT'],
#  ['G0450A 10 5', 'ARCH CAP GROUP LTD', 'ORD'],
#  ['G0450A 90 5', 'ARCH CAP GROUP LTD'],
#  ['G0450A 95 5', 'ARCH CAP GROUP LTD'],
#  ['G05384 10 5', 'ASPEN INSURANCE HOLDINGS LTD'],
#  ['G0692U 10 9', 'AXIS CAPITAL HOLDINGS', 'CALL', 'PUT', 'SHS'],
#  ['G07644 10 0', 'BANK OF BERMUDA LTD', 'SHS', 'DELETED'],
#  ['G1150G 11 1', 'ACCENTURE LTD BERMUDA', 'CL A'],
#  ['G1150G 90 1', 'ACCENTURE LTD BERMUDA'],
#  ['G1150G 95 1', 'ACCENTURE LTD BERMUDA', 'CALL', 'PUT'],
#  ['G16962 10 5', 'BUNGE LIMITED', 'COM'],
#  ['G16962 90 5', 'BUNGE LIMITED'],
#  ['G16962 95 5', 'BUNGE LIMITED', 'CALL', 'PUT'],
#  ['G20045 20 2', 'CENTRAL EUROPEAN MEDIA ENTRP', 'CL A NEW'],
#  ['G2108N 10 9', 'CHINADOTCOM CORP', 'CL A'],
#  ['G2108N 90 9', 'CHINADOTCOM CORP'],
#  ['G2108N 95 9', 'CHINADOTCOM CORP', 'CALL', 'PUT'],
#  ['G21082 10 5', 'CHINA YUCHAI INTL LTD', 'COM'],
#  ['G21082 90 5', 'CHINA YUCHAI INTL LTD'],
#  ['G21082 95 5', 'CHINA YUCHAI INTL LTD', 'CALL', 'PUT'],
#  ['G2110R 10 6', 'CHIPMOS TECH BERMUDA LTD', 'SHS'],
#  ['G2110R 90 6', 'CHIPMOS TECH BERMUDA LTD'],
#  ['G2110R 95 6', 'CHIPMOS TECH BERMUDA LTD'],
#  ['G23773 10 7', 'CONSOLIDATED WATER CO INC'],
#  ['G24182 10 0', 'COOPER INDS LTD'],
#  ['G24182 90 0', 'COOPER INDS LTD'],
#  ['G24182 95 0', 'COOPER INDS LTD'],
#  ['G2519Y 10 8', 'CREDICORP LTD'],
#  ['G27545 10 5', 'DF CHINA TECHNOLOGY INC'],
#  ['G28471 10 3', 'DSG INTL LTD', 'CALL', 'PUT', 'ORD', 'CL A', 'COM'],
#  ['G29539 16 3', 'ELAN CORP PLC', '*W EXP 08/31/200'],
#  ['G30397 10 6', 'ENDURANCE SPECIALTY HLDGS LT'],
#  ['G31611 10 9', 'XCELERA INC'],
#  ['G31611 90 9', 'XCELERA INC'],
#  ['G31611 95 9', 'XCELERA INC'],
#  ['G32030 10 1', 'EURO TECH HOLDINGS CO LTD'],
#  ['G3223R 10 8', 'EVEREST RE GROUP LTD'],
#  ['G3223R 90 8', 'EVEREST RE GROUP LTD'],
#  ['G3223R 95 8', 'EVEREST RE GROUP LTD', 'SHS', 'COM', 'CALL', 'PUT', 'ORD'],
#  ['G36738 10 5', 'FRESH DEL MONTE PRODUCE INC', 'ORD'],
#  ['G36738 90 5', 'FRESH DEL MONTE PRODUCE INC'],
#  ['G36738 95 5', 'FRESH DEL MONTE PRODUCE INC'],
#  ['G3682E 12 7', 'FRONTLINE LTD'],
#  ['G37260 10 9', 'GARMIN LTD'],
#  ['G37260 90 9', 'GARMIN LTD'],
#  ['G37260 95 9', 'GARMIN LTD', 'CALL', 'PUT', 'ORD'],
#  ['G3921A 17 5', 'GLOBAL CROSSING LTD', 'SHS NEW'],
#  ['G3921A 90 5', 'GLOBAL CROSSING LTD', 'CALL', 'ADDED'],
#  ['G3921A 95 5', 'GLOBAL CROSSING LTD', 'PUT'],
#  ['G3930E 10 1', 'GLOBALSANTAFE CORP', 'SHS', 'Page', '3', 'ADDED'],
#  ['G3930E 90 1', 'GLOBALSANTAFE CORP'],
#  ['G3930E 95 1', 'GLOBALSANTAFE CORP'],
#  ['G39300 10 1', 'GLOBAL SOURCES LTD'],
#  ['G39320 10 9', 'GLOBAL-TECH APPLIANCES INC'],
#  ['G4388N 10 6', 'HELEN OF TROY CORP LTD'],
#  ['G4388N 90 6', 'HELEN OF TROY CORP LTD'],
#  ['G4388N 95 6', 'HELEN OF TROY CORP LTD'],
#  ['G4481U 10 6', 'HIGHWAY HLDGS LTD'],
#  ['G4776G 10 1', 'INGERSOLL-RAND COMPANY LTD'],
#  ['G4776G 90 1', 'INGERSOLL-RAND COMPANY LTD'],
#  ['G4776G 95 1',
#   'INGERSOLL-RAND COMPANY LTD',
#   'CALL',
#   'PUT',
#   'ORD',
#   'COM',
#   'CL A'],
#  ['G4911N 30 0', 'INTERWAVE COMMUNCTNS INTL LT', 'SHS NEW'],
#  ['G4933P 10 1', 'IPC HLDGS LTD', 'ORD'],
#  ['G4933P 90 1', 'IPC HLDGS LTD'],
#  ['G4933P 95 1', 'IPC HLDGS LTD'],
#  ['G5138L 10 0', 'JINPAN INTL LTD'],
#  ['G5299G 10 6', 'KNIGHTSBRIDGE TANKERS LTD'],
#  ['G55312 10 5', 'LJ INTL INC', 'CALL', 'PUT', 'ORD'],
#  ['G55312 11 3', 'LJ INTL INC', '*W EXP 04/15/200'],
#  ['G5876H 10 5', 'MARVELL TECHNOLOGY GROUP LTD', 'ORD'],
#  ['G5876H 90 5', 'MARVELL TECHNOLOGY GROUP LTD'],
#  ['G5876H 95 5', 'MARVELL TECHNOLOGY GROUP LTD', 'CALL', 'PUT'],
#  ['G6052F 10 3', 'MAX RE CAPITAL LTD HAMILTON', 'SHS'],
#  ['G6052F 90 3', 'MAX RE CAPITAL LTD HAMILTON'],
#  ['G6052F 95 3', 'MAX RE CAPITAL LTD HAMILTON'],
#  ['G62185 10 6', 'MONTPELIER RE HOLDINGS LTD'],
#  ['G6359F 10 3', 'NABORS INDUSTRIES LTD'],
#  ['G6359F 90 3', 'NABORS INDUSTRIES LTD'],
#  ['G6359F 95 3', 'NABORS INDUSTRIES LTD', 'CALL', 'PUT', 'SHS'],
#  ['G65422 10 0', 'NOBLE CORPORATION', 'SHS'],
#  ['G65422 90 0', 'NOBLE CORPORATION'],
#  ['G65422 95 0', 'NOBLE CORPORATION', 'CALL', 'PUT'],
#  ['G65773 10 6', 'NORDIC AMERICAN TANKER SHIPP'],
#  ['G6674P 10 9', 'NOVEL DENIM HLDGS LTD'],
#  ['G67543 10 1', 'OPENTV CORP'],
#  ['G67543 90 1', 'OPENTV CORP'],
#  ['G67543 95 1', 'OPENTV CORP'],
#  ['G67743 10 7', 'ORIENT-EXPRESS HOTELS LTD'],
#  ['G6797E 10 6', 'O2MICRO INTERNATIONAL LIMITE'],
#  ['G6797E 90 6', 'O2MICRO INTERNATIONAL LIMITE'],
#  ['G6797E 95 6',
#   'O2MICRO INTERNATIONAL LIMITE',
#   'COM',
#   'ORD',
#   'CL A',
#   'CALL',
#   'PUT'],
#  ['G6852T 10 5', 'PARTNERRE LTD', 'COM'],
#  ['G6852T 90 5', 'PARTNERRE LTD'],
#  ['G6852T 95 5', 'PARTNERRE LTD'],
#  ['G69586 10 8', 'PEAK INTL LTD'],
#  ['G7127P 10 0', 'PLATINUM UNDERWRITER HLDGS L', 'CALL', 'PUT', 'ORD', 'COM'],
#  ['G7127P 90 0', 'PLATINUM UNDERWRITER HLDGS L'],
#  ['G7127P 95 0', 'PLATINUM UNDERWRITER HLDGS L', 'CALL', 'PUT'],
#  ['G73018 10 6', 'PXRE GROUP LTD'],
#  ['G7303A 10 9', 'QIAO XING UNIVERSAL TELEPHON'],
#  ['G7303A 90 9', 'QIAO XING UNIVERSAL TELEPHON'],
#  ['G7303A 95 9', 'QIAO XING UNIVERSAL TELEPHON', 'COM', 'ORD', 'CALL', 'PUT'],
#  ['G7342H 10 7', 'RADICA GAMES LTD', 'ORD'],
#  ['G7342H 90 7', 'RADICA GAMES LTD'],
#  ['G7342H 95 7', 'RADICA GAMES LTD', 'CALL', 'PUT'],
#  ['G7496G 10 3', 'RENAISSANCE RE HLDGS LTD', 'COM'],
#  ['G7496G 90 3', 'RENAISSANCE RE HLDGS LTD'],
#  ['G7496G 95 3', 'RENAISSANCE RE HLDGS LTD'],
#  ['G7885T 10 4', 'SCOTTISH RE GROUP LTD'],
#  ['G7945J 10 4', 'SEAGATE TECHNOLOGY'],
#  ['G7945J 90 4', 'SEAGATE TECHNOLOGY'],
#  ['G7945J 95 4', 'SEAGATE TECHNOLOGY'],
#  ['G81365 10 1', 'SILVERSTAR HLDGS LTD'],
#  ['G81477 10 4', 'SINA CORP'],
#  ['G81477 90 4', 'SINA CORP'],
#  ['G81477 95 4', 'SINA CORP', 'CALL', 'PUT', 'ORD', 'SHS'],
#  ['G84922 10 6', 'STEWART W P & CO LTD'],
#  ['G87210 10 3', 'UTI WORLDWIDE INC', 'COM', 'ORD'],
#  ['G88653 12 9', 'TIERS PRINCIPAL PROTECTED TR', 'S&P 01-19 TR'],
#  ['G88653 20 2', 'TIERS PRINCIPAL PROTECTED TR'],
#  ['G88653 40 0', 'TIERS PRINCIPAL PROTECTED TR'],
#  ['G88653 50 9', 'TIERS PRINCIPAL PROTECTED TR'],
#  ['G88653 60 8', 'TIERS PRINCIPAL PROTECTED TR'],
#  ['G88653 70 7', 'TIERS PRINCIPAL PROTECTED TR'],
#  ['G88653 80 6', 'TIERS PRINCIPAL PROTECTED TR'],
#  ['G88653 88 9', 'TIERS PRINCIPAL PROTECTED TR'],
#  ['G8915Z 10 2', 'HILFIGER TOMMY CORP'],
#  ['G8915Z 90 2', 'HILFIGER TOMMY CORP'],
#  ['G8915Z 95 2', 'HILFIGER TOMMY CORP'],
#  ['G89935 10 3', 'TRAMFORD INTL LTD'],
#  ['G90078 10 9', 'TRANSOCEAN INC'],
#  ['G90078 90 9', 'TRANSOCEAN INC'],
#  ['G90078 95 9', 'TRANSOCEAN INC'],
#  ['G9108L 10 8', 'TSAKOS ENERGY NAVIGATION LTD'],
#  ['G9456A 10 0',
#   'GOLAR LNG LTD BERMUDA',
#   'TIERS2000-2007',
#   'TIERS2000-2014',
#   'TIERS 2000-2013',
#   'S&P 2001 11 TR',
#   'TIERS 2001-13',
#   'DJIA 2001-26',
#   '2002-1 TR CTF',
#   'ORD',
#   'CALL',
#   'PUT',
#   'SHS'],
#  ['G95089 10 1', 'WEATHERFORD INTERNATIONAL LT', 'COM'],
#  ['G95089 90 1', 'WEATHERFORD INTERNATIONAL LT'],
#  ['G95089 95 1', 'WEATHERFORD INTERNATIONAL LT', 'CALL', 'PUT'],
#  ['G9618E 10 7', 'WHITE MTNS INS GROUP LTD'],
#  ['G96655 10 8', 'WILLIS GROUP HOLDINGS LTD'],
#  ['G96655 90 8', 'WILLIS GROUP HOLDINGS LTD'],
#  ['G96655 95 8', 'WILLIS GROUP HOLDINGS LTD', 'COM', 'SHS', 'CALL', 'PUT'],
#  ['G9825R 10 7', 'XOMA LTD', 'ORD'],
#  ['G9825R 90 7', 'XOMA LTD'],
#  ['G9825R 95 7', 'XOMA LTD', 'CALL', 'PUT'],
#  ['G98255 10 5', 'XL CAP LTD', 'CL A'],
#  ['G98255 90 5', 'XL CAP LTD'],
#  ['G98255 95 5', 'XL CAP LTD', 'CALL', 'PUT'],
#  ['H01301 10 2', 'ALCON INC', 'COM SHS'],
#  ['H01301 90 2', 'ALCON INC', 'CALL'],
#  ['H01301 95 2', 'ALCON INC', 'PUT'],
#  ['H8920M 85 5', 'UBS AG', 'NAMEN AKT'],
#  ['H8920M 90 5', 'UBS AG'],
#  ['H8920M 95 5', 'UBS AG'],
#  ['L20708 10 0', 'CRONOS GROUP S A'],
#  ['L63631 10 2', 'METRO INTERNATIONAL S A'],
#  ['L63631 11 0',
#   'METRO INTERNATIONAL S A',
#   'CALL',
#   'PUT',
#   'SHS',
#   'CL A',
#   'CL B',
#   'DELETED'],
#  ['L6388F 11 0', 'MILLICOM INTL CELLULAR S A', 'SHS NEW'],
#  ['L6388F 90 0', 'MILLICOM INTL CELLULAR S A'],
#  ['L6388F 95 0', 'MILLICOM INTL CELLULAR S A'],
#  ['L8137F 10 2', 'SBS BROADCASTING SA'],
#  ['M01773 10 6', 'ACS TECH 80 LTD'],
#  ['M0392N 10 1', 'ALADDIN KNOWLEDGE SYS LTD'],
#  ['M0861T 10 0', 'ALVARION LTD'],
#  ['M0861T 90 0', 'ALVARION LTD'],
#  ['M0861T 95 0', 'ALVARION LTD', 'CALL', 'PUT', 'ORD', 'SHS'],
#  ['M14925 10 7', 'AREL COMMUNICATIONS & SOFTWA', 'COM'],
#  ['M15332 10 5', 'ATTUNITY LTD'],
#  ['M15342 10 4', 'AUDIOCODES LTD'],
#  ['M15342 90 4', 'AUDIOCODES LTD'],
#  ['M15342 95 4', 'AUDIOCODES LTD', 'ORD', 'CALL', 'PUT'],
#  ['M15633 10 6', 'BACKWEB TECHNOLOGIES LTD', 'ORD'],
#  ['M15633 90 6', 'BACKWEB TECHNOLOGIES LTD'],
#  ['M15633 95 6', 'BACKWEB TECHNOLOGIES LTD', 'CALL', 'PUT'],
#  ['M18955 10 0', 'BARAN GROUP LTD', 'NIS ORD SHS'],
#  ['M20115 13 1', 'BOS BETTER ONLINE SOLUTIONS', 'SHS NEW'],
#  ['M20157 10 9', 'BLUEPHOENIX SOLUTIONS LTD'],
#  ['M20330 10 2', 'ROBO GROUP TEK LTD'],
#  ['M20791 10 5', 'CAMTEK LTD'],
#  ['M22013 10 2', 'CERAGON NETWORKS LTD'],
#  ['M22013 90 2', 'CERAGON NETWORKS LTD'],
#  ['M22013 95 2', 'CERAGON NETWORKS LTD', 'SHS', 'ORD', 'CALL', 'PUT'],
#  ['M22465 10 4', 'CHECK POINT SOFTWARE TECH LT', 'ORD'],
#  ['M22465 90 4', 'CHECK POINT SOFTWARE TECH LT', 'CALL'],
#  ['M22465 95 4', 'CHECK POINT SOFTWARE TECH LT', 'PUT'],
#  ['M23798 10 7', 'CIMATRON LTD'],
#  ['M25082 10 4', 'CLICKSOFTWARE TECHNOLOGIES L'],
#  ['M25596 10 3', 'COMMTOUCH SOFTWARE LTD'],
#  ['M25596 90 3', 'COMMTOUCH SOFTWARE LTD'],
#  ['M25596 95 3', 'COMMTOUCH SOFTWARE LTD'],
#  ['M25722 10 5', 'COMPUGEN LTD'],
#  ['M29925 10 0', 'ECTEL LTD'],
#  ['M3760D 10 1', 'ELBIT SYS LTD'],
#  ['M3760D 90 1', 'ELBIT SYS LTD'],
#  ['M3760D 95 1', 'ELBIT SYS LTD'],
#  ['M37605 10 8', 'ELBIT MEDICAL IMAGING LTD'],
#  ['M40168 10 2', 'ELSCINT LTD NEW'],
#  ['M40184 10 9', 'ELTEK LTD'],
#  ['M47095 10 0', 'FUNDTECH LTD'],
#  ['M47095 90 0', 'FUNDTECH LTD'],
#  ['M47095 95 0', 'FUNDTECH LTD'],
#  ['M51474 11 8', 'GILAT SATELLITE NETWORKS LTD'],
#  ['M52020 10 0', 'GIVEN IMAGING'],
#  ['M52020 90 0', 'GIVEN IMAGING'],
#  ['M52020 95 0', 'GIVEN IMAGING'],
#  ['M52523 10 3', 'WILLI G FOOD INTL LTD'],
#  ['M5296L 13 5', 'HEALTHCARE TECHNOLOGIES LTD'],
#  ['M56595 10 7', 'INTERNET GOLD-GOLDEN LINES L'],
#  ['M6184R 10 1', 'JACADA LTD'],
#  ['M6706C 10 3', 'LANOPTICS LTD'],
#  ['M6772H 10 1', 'LIPMAN ELECTRONIC ENGINEERIN'],
#  ['M6778Q 10 5', 'LUMENIS LTD'],
#  ['M6778Q 90 5', 'LUMENIS LTD'],
#  ['M6778Q 95 5',
#   'LUMENIS LTD',
#   'ORD',
#   'CALL',
#   'PUT',
#   'SHS NEW',
#   'ORD SHS',
#   'COM',
#   'SHS'],
#  ['M6786D 10 4', 'MAGAL SECURITY SYS LTD', 'ORD'],
#  ['M69676 10 0', 'MER TELEMANAGEMENT SOLUTIONS', 'ORD'],
#  ['M69897 10 2', 'METALINK LTD'],
#  ['M69897 90 2', 'METALINK LTD', 'ORD', 'CALL', 'ADDED', 'DELETED'],
#  ['M69897 95 2', 'METALINK LTD'],
#  ['M70240 10 2', 'MIND C T I LTD'],
#  ['M7061C 10 0', 'M SYS FLASH DISK PIONEERS LT'],
#  ['M7061C 90 0', 'M SYS FLASH DISK PIONEERS LT'],
#  ['M7061C 95 0', 'M SYS FLASH DISK PIONEERS LT', 'PUT', 'ORD', 'CALL'],
#  ['M7516K 10 3', 'NOVA MEASURING INSTRUMENTS L', 'COM'],
#  ['M75165 10 6', 'NUR MACROPRINTERS LTD'],
#  ['M7524R 10 8', 'OPTIBASE LTD'],
#  ['M75253 10 0', 'ORBOTECH LTD'],
#  ['M75253 90 0', 'ORBOTECH LTD'],
#  ['M75253 95 0', 'ORBOTECH LTD'],
#  ['M7531S 20 6', 'ORCKIT COMMUNICATIONS LTD'],
#  ['M81863 10 8', 'RADA ELECTR INDS LTD'],
#  ['M81865 10 3', 'RADCOM LTD'],
#  ['M81867 10 9', 'RADVIEW SOFTWARE LTD'],
#  ['M81869 10 5', 'RADVISION LTD'],
#  ['M81869 90 5', 'RADVISION LTD'],
#  ['M81869 95 5', 'RADVISION LTD', 'ORD', 'CALL', 'PUT', 'SHS NEW'],
#  ['M81873 10 7', 'RADWARE LTD', 'ORD'],
#  ['M81873 90 7', 'RADWARE LTD'],
#  ['M81873 95 7', 'RADWARE LTD'],
#  ['M8215N 10 9', 'RIT TECHNOLOGIES LTD'],
#  ['M8215W 10 9', 'RETALIX LTD'],
#  ['M84116 10 8', 'SILICOM LTD'],
#  ['M8737E 10 8', 'TARO PHARMACEUTICAL INDS LTD'],
#  ['M8737E 90 8', 'TARO PHARMACEUTICAL INDS LTD'],
#  ['M8737E 95 8', 'TARO PHARMACEUTICAL INDS LTD', 'CALL', 'PUT', 'ORD'],
#  ['M8740S 22 7', 'TAT TECHNOLOGIES LTD', 'ORD NEW'],
#  ['M8743P 10 5', 'TECNOMATIX TECHNOLOGIES LTD', 'ORD'],
#  ['M8743P 90 5', 'TECNOMATIX TECHNOLOGIES LTD'],
#  ['M8743P 95 5', 'TECNOMATIX TECHNOLOGIES LTD'],
#  ['M87482 10 1', 'TEFRON LTD'],
#  ['M87896 10 2', 'TOP IMAGE SYSTEMS LTD'],
#  ['M8791A 10 9', 'ON TRACK INNOVATION LTD', 'CALL', 'PUT', 'ORD', 'SHS'],
#  ['M87915 10 0', 'TOWER SEMICONDUCTOR LTD', 'ORD'],
#  ['M87915 90 0', 'TOWER SEMICONDUCTOR LTD'],
#  ['M87915 95 0', 'TOWER SEMICONDUCTOR LTD', 'CALL', 'PUT'],
#  ['M87915 13 4', 'TOWER SEMICONDUCTOR LTD', '*W EXP 10/31/200'],
#  ['M88258 10 4', 'TTI TEAM TELECOM INTL LTD'],
#  ['M97385 11 2', 'VERISITY LTD'],
#  ['M97385 90 2', 'VERISITY LTD'],
#  ['M97385 95 2', 'VERISITY LTD'],
#  ['M97540 11 2', 'VIRYANET LTD'],
#  ['M97601 10 4', 'VOCALTEC COMMUNICATIONS LTD'],
#  ['N07045 10 2', 'ASM INTL N V'],
#  ['N07045 90 2', 'ASM INTL N V'],
#  ['N07045 95 2', 'ASM INTL N V', 'ORD', 'CALL', 'PUT', 'SHS NEW', 'COM'],
#  ['N07059 11 1', 'ASML HLDG NV', 'N Y SHS'],
#  ['N07059 90 1', 'ASML HLDG NV'],
#  ['N07059 95 1', 'ASML HLDG NV', 'CALL', 'PUT'],
#  ['N20935 20 6', 'CNH GLOBAL N V', 'SHS NEW'],
#  ['N20935 90 6', 'CNH GLOBAL N V'],
#  ['N20935 95 6', 'CNH GLOBAL N V', 'CALL', 'PUT'],
#  ['N22717 10 7', 'CORE LABORATORIES N V', 'COM'],
#  ['N22717 90 7', 'CORE LABORATORIES N V'],
#  ['N22717 95 7', 'CORE LABORATORIES N V'],
#  ['N43837 10 8', 'ICTS INTERNATIONAL NV'],
#  ['N5665B 10 5', 'METRON TECHNOLOGY N V'],
#  ['N6748L 10 2', 'ORTHOFIX INTL N V'],
#  ['N72482 10 7', 'QIAGEN N V'],
#  ['N72482 90 7', 'QIAGEN N V'],
#  ['N72482 95 7', 'QIAGEN N V', 'CALL', 'PUT', 'COM', 'ORD'],
#  ['N7716A 15 1', 'SAPIENS INTL CORP N V', 'SHS NEW'],
#  ['N88795 10 4', 'TRIPLE P N V'],
#  ['P16994 13 2', 'BANCO LATINOAMERICANO DE EXP'],
#  ['P21277 10 1', 'CARLISLE HLDGS LTD'],
#  ['P36209 10 7', 'ELAMEX S A DE C V'],
#  ['P6065Y 10 7', 'KERZNER INTERNATIONAL LTD', 'COM', 'CL E', 'ORD', 'SHS'],
#  ['P8744Y 10 2', 'STEINER LEISURE LTD', 'ORD'],
#  ['P8744Y 90 2', 'STEINER LEISURE LTD'],
#  ['P8744Y 95 2', 'STEINER LEISURE LTD'],
#  ['Q7759R 10 0', 'PROGEN INDS LTD'],
#  ['V3267N 10 7', 'EXCEL MARITIME CARRIERS LTD'],
#  ['V7780T 10 3', 'ROYAL CARIBBEAN CRUISES LTD'],
#  ['V7780T 90 3', 'ROYAL CARIBBEAN CRUISES LTD'],
#  ['V7780T 95 3', 'ROYAL CARIBBEAN CRUISES LTD'],
#  ['V7780Z 10 9', 'ROYAL OLYMPIC CRUISE LINES I'],
#  ['V8726M 10 3', 'STELMAR SHIPPING LTD'],
#  ['Y02516 10 5', 'ASE TEST LTD'],
#  ['Y02516 90 5', 'ASE TEST LTD'],
#  ['Y02516 95 5', 'ASE TEST LTD', 'CALL', 'PUT', 'ORD', 'COM'],
#  ['Y1775U 10 7', 'CREATIVE TECHNOLOGY LTD', 'ORD'],
#  ['Y1775U 90 7', 'CREATIVE TECHNOLOGY LTD'],
#  ['Y1775U 95 7', 'CREATIVE TECHNOLOGY LTD', 'CALL', 'PUT'],
#  ['Y2573F 10 2', 'FLEXTRONICS INTL LTD', 'ORD'],
#  ['Y2573F 90 2', 'FLEXTRONICS INTL LTD'],
#  ['Y2573F 95 2', 'FLEXTRONICS INTL LTD'],
#  ['Y2692M 10 3', 'GENERAL MARITIME CORP'],
#  ['Y2711Y 10 4', 'GIGAMEDIA LTD'],
#  ['Y6476W 10 4', 'OMI CORP NEW'],
#  ['Y6476W 90 4', 'OMI CORP NEW'],
#  ['Y6476W 95 4', 'OMI CORP NEW'],
#  ['Y66183 10 7', 'PACIFIC INTERNET LTD'],
#  ['Y8564W 10 3', 'TEEKAY SHIPPING MARSHALL ISL'],
#  ['Y8564W 90 3', 'TEEKAY SHIPPING MARSHALL ISL'],
#  ['Y8564W 95 3', 'TEEKAY SHIPPING MARSHALL ISL'],
#  ['000360 20 6', 'AAON INC'],
#  ['000361 10 5', 'AAR CORP'],
#  ['000361 90 5', 'AAR CORP'],
#  ['000361 95 5', 'AAR CORP'],
#  ['000375 20 4', 'ABB LTD'],
#  ['000400 10 1',
#   'ABC BANCORP',
#   'CALL',
#   'PUT',
#   'SHS',
#   'ORD',
#   'COM',
#   'COM PAR $0.004',
#   'SPONSORED ADR'],
#  ['00079F BA 9', 'ABN AMRO BK N V LONDON BRH', 'DEBT 14.000% 3/1'],
#  ['00079F BF 8', 'ABN AMRO BK N V LONDON BRH', 'DEBT 10.000% 4/2', 'ADDED'],
#  ['00079F BN 1', 'ABN AMRO BK N V LONDON BRH', 'DEBT 11.750% 8/1'],
#  ['00079F BW 1', 'ABN AMRO BK N V LONDON BRH', 'DEBT 10.000% 9/2'],
#  ['00079F BY 7', 'ABN AMRO BK N V LONDON BRH', 'DEBT 11.000%10/0'],
#  ['00079F CC 4', 'ABN AMRO BK N V LONDON BRH', 'DEBT 12.000%10/2', 'ADDED'],
#  ['00079F CK 6', 'ABN AMRO BK N V LONDON BRH', 'DEBT 12.000%12/1', 'ADDED'],
#  ['00079F CQ 3', 'ABN AMRO BK N V LONDON BRH', 'DEBT 10.000% 1/2', 'ADDED'],
#  ['00079F CS 9', 'ABN AMRO BK N V LONDON BRH', 'DEBT 12.000% 2/0', 'ADDED'],
#  ['00086T 10 3', 'A C MOORE ARTS & CRAFTS INC', 'COM'],
#  ['00086T 90 3', 'A C MOORE ARTS & CRAFTS INC'],
#  ['00086T 95 3', 'A C MOORE ARTS & CRAFTS INC', 'CALL', 'PUT'],
#  ['00088U 10 8', 'A D A M INC', 'COM'],
#  ['000881 10 2', 'A CONSULTING TEAM INC', 'COM', 'DELETED'],
#  ['000881 20 1', 'A CONSULTING TEAM INC', 'COM NEW', 'ADDED'],
#  ['000886 AB 7', 'A D C TELECOMMUNICATIONS', 'FRNT         6/1'],
#  ['000886 AD 3', 'A D C TELECOMMUNICATIONS', 'NOTE  1.000% 6/1'],
#  ['000886 10 1', 'A D C TELECOMMUNICATIONS', 'COM'],
#  ['000886 90 1', 'A D C TELECOMMUNICATIONS'],
#  ['000886 95 1', 'A D C TELECOMMUNICATIONS', 'CALL', 'PUT'],
#  ['00089C 10 7', 'ADE CORP MASS', 'COM'],
#  ['00089C 90 7', 'ADE CORP MASS'],
#  ['00089C 95 7', 'ADE CORP MASS'],
#  ['000912 10 5', 'ACM INCOME FUND INC'],
#  ['000918 10 2', 'ACM GOVT OPPORTUNITY FD INC'],
#  ['000919 10 0', 'ACM MANAGED INCOME FD INC'],
#  ['000937 10 2', 'ABN AMRO HLDG NV'],
#  ['000937 90 2', 'ABN AMRO HLDG NV'],
#  ['000937 95 2', 'ABN AMRO HLDG NV'],
#  ['000942 10 2', 'ACM MUN SECS INCOME FD INC'],
#  ['000945 AC 9', 'ADT OPERATIONS'],
#  ['000949 10 7', 'ACM MANAGED DLR INCOME FD'],
#  ['000955 10 4', 'ACT TELECONFERENCING INC'],
#  ['000957 10 0',
#   'ABM INDS INC',
#   'CALL',
#   'PUT',
#   'COM',
#   'SPONSORED ADR',
#   'NOTE         7/0'],
#  ['000957 90 0', 'ABM INDS INC'],
#  ['000957 95 0', 'ABM INDS INC'],
#  ['001031 10 3', 'AEP INDS INC'],
#  ['00104G 10 9', 'AESP INC'],
#  ['00104H 10 7', 'AEW REAL ESTATE INCOME FD'],
#  ['001055 10 2', 'AFLAC INC'],
#  ['001055 90 2', 'AFLAC INC'],
#  ['001055 95 2', 'AFLAC INC', 'CALL', 'PUT', 'COM'],
#  ['001084 10 2', 'AGCO CORP', 'COM'],
#  ['001084 90 2', 'AGCO CORP'],
#  ['001084 95 2', 'AGCO CORP', 'CALL', 'PUT'],
#  ['001204 10 6', 'AGL RES INC', 'COM'],
#  ['001204 90 6', 'AGL RES INC'],
#  ['001204 95 6', 'AGL RES INC', 'CALL', 'PUT'],
#  ['001250 10 9', 'AG SVCS AMER INC', 'COM', 'DELETED'],
#  ['00130H AN 5', 'AES CORP'],
#  ['00130H 10 5', 'AES CORP'],
#  ['00130H 90 5', 'AES CORP'],
#  ['00130H 95 5', 'AES CORP', 'SDCV  4.500% 8/1', 'COM', 'CALL', 'PUT'],
#  ['001547 10 8', 'AK STL HLDG CORP', 'COM'],
#  ['001547 90 8', 'AK STL HLDG CORP'],
#  ['001547 95 8', 'AK STL HLDG CORP'],
#  ['00163T 10 9', 'AMB PROPERTY CORP'],
#  ['001669 10 0', 'AMC ENTMT INC'],
#  ['001669 90 0', 'AMC ENTMT INC'],
#  ['001669 95 0', 'AMC ENTMT INC', 'CALL', 'PUT', 'COM'],
#  ['00167K 40 1', 'AMDL INC', 'COM PAR $0.001'],
#  ['001735 10 9', 'AMLI RESIDENTIAL PPTYS TR', 'SH BEN INT'],
#  ['001744 10 1', 'AMN HEALTHCARE SERVICES INC', 'COM'],
#  ['001744 90 1', 'AMN HEALTHCARE SERVICES INC'],
#  ['001744 95 1', 'AMN HEALTHCARE SERVICES INC', 'CALL', 'PUT'],
#  ['001765 BB 1', 'AMR CORP', 'NOTE  4.500% 2/1', 'ADDED'],
#  ['001765 10 6', 'AMR CORP'],
#  ['001765 90 6', 'AMR CORP', 'COM', 'CALL'],
#  ['001765 95 6', 'AMR CORP'],
#  ['00180C 10 5', 'AMX CORP NEW'],
#  ['00185E 10 6', 'APAC CUSTOMER SERVICES INC'],
#  ['00185E 90 6', 'APAC CUSTOMER SERVICES INC'],
#  ['00185E 95 6', 'APAC CUSTOMER SERVICES INC'],
#  ['001853 10 0', 'APA OPTICS INC'],
#  ['001912 30 2', 'ASA INTL LTD', 'PUT', 'COM', 'CALL', 'COM PAR $0.01'],
#  ['001941 10 3', 'ATI TECHNOLOGIES INC', 'COM'],
#  ['001941 90 3', 'ATI TECHNOLOGIES INC'],
#  ['001941 95 3', 'ATI TECHNOLOGIES INC', 'CALL', 'PUT'],
#  ['001957 50 5', 'AT&T CORP', 'COM NEW'],
#  ['001957 90 5', 'AT&T CORP'],
#  ['001957 95 5', 'AT&T CORP'],
#  ['001963 10 7', 'A S V INC'],
#  ['001984 10 3', 'AMB FINL CORP'],
#  ['00202J 10 4', 'AP PHARMA INC'],
#  ['00203R 10 5', 'APT SATELLITE HOLDINGS LTD'],
#  ['00205P 10 7', 'ASB FINL CORP'],
#  ['002050 10 2', 'ASA LTD'],
#  ['002050 90 2', 'ASA LTD'],
#  ['002050 95 2', 'ASA LTD'],
#  ['00207D AE 2', 'ASM INTL NV'],
#  ['00207R AC 5', 'ATMI INC'],
#  ['00207R 10 1', 'ATMI INC'],
#  ['00207R 90 1', 'ATMI INC'],
#  ['00207R 95 1', 'ATMI INC'],
#  ['00208B 10 5', 'ASAT HLDGS LTD'],
#  ['00208J 10 8', 'ATP OIL & GAS CORP'],
#  ['00208W 10 9', 'A S DAMPSKIBSSELSKABET TORM'],
#  ['002083 10 3', 'ATS MED INC'],
#  ['00209A 10 6', 'AT&T WIRELESS SVCS INC'],
#  ['00209A 90 6', 'AT&T WIRELESS SVCS INC'],
#  ['00209A 95 6',
#   'AT&T WIRELESS SVCS INC',
#   'CALL',
#   'PUT',
#   'COM',
#   'SPONSORED ADR',
#   'NOTE  5.250% 5/1',
#   'NOTE  5.250%11/1'],
#  ['00209C 10 2', 'ATC HEALTHCARE INC', 'CL A'],
#  ['00209H 10 1', 'ATA HOLDINGS CORP'],
#  ['002255 10 7', 'AU OPTRONICS CORP'],
#  ['002346 10 4', 'AVI BIOPHARMA INC'],
#  ['002346 90 4', 'AVI BIOPHARMA INC'],
#  ['002346 95 4', 'AVI BIOPHARMA INC', 'COM', 'SPONSORED ADR', 'CALL', 'PUT'],
#  ['002444 10 7', 'AVX CORP NEW', 'COM'],
#  ['002444 90 7', 'AVX CORP NEW'],
#  ['002444 95 7', 'AVX CORP NEW', 'CALL', 'PUT'],
#  ['002457 10 9', 'AXM PHARMA INC', 'COM', 'ADDED'],
#  ['002458 10 7', 'AXS-ONE INC'],
#  ['00246W 10 3', 'AXT INC'],
#  ['00246W 90 3', 'AXT INC'],
#  ['00246W 95 3', 'AXT INC'],
#  ['002474 10 4', 'AZZ INC'],
#  ['00252W 10 4', 'AAIPHARMA INC'],
#  ['00252W 90 4', 'AAIPHARMA INC'],
#  ['00252W 95 4', 'AAIPHARMA INC'],
#  ['00253U 10 7', 'AASTROM BIOSCIENCES INC'],
#  ['002535 20 1', 'AARON RENTS INC'],
#  ['002535 30 0', 'AARON RENTS INC'],
#  ['002564 10 2', 'ABATIX CORP'],
#  ['002567 10 5', 'ABAXIS INC'],
#  ['002567 90 5', 'ABAXIS INC'],
#  ['002567 95 5', 'ABAXIS INC', 'COM', 'CALL', 'PUT', 'CL A'],
#  ['002824 10 0', 'ABBOTT LABS', 'COM'],
#  ['002824 90 0', 'ABBOTT LABS'],
#  ['002824 95 0', 'ABBOTT LABS'],
#  ['002893 10 5', 'ABER DIAMOND CORP'],
#  ['002896 20 7', 'ABERCROMBIE & FITCH CO'],
#  ['002896 90 7', 'ABERCROMBIE & FITCH CO'],
#  ['002896 95 7', 'ABERCROMBIE & FITCH CO', 'CALL', 'PUT', 'COM', 'CL A'],
#  ['002920 70 0', 'ABBEY NATL PLC', 'ADR PRF B7.375'],
#  ['002920 80 9', 'ABBEY NATL PLC'],
#  ['003009 10 7', 'ABERDEEN ASIA PACIFIC INCOM', 'GDR', 'COM'],
#  ['003011 10 3', 'ABERDEEN AUSTRALIA EQTY FD I'],
#  ['003013 10 9', 'ABERDEEN GLOBAL INCOME FD IN'],
#  ['00339B AB 3', 'ABGENIX INC'],
#  ['00339B 10 7', 'ABGENIX INC'],
#  ['00339B 90 7', 'ABGENIX INC'],
#  ['00339B 95 7', 'ABGENIX INC'],
#  ['003390 10 1', 'ABIGAIL ADAMS NATL BANCORP I'],
#  ['00350P 10 0', 'ABINGTON BANCORP INC NEW'],
#  ['003654 10 0', 'ABIOMED INC'],
#  ['003654 90 0', 'ABIOMED INC'],
#  ['003654 95 0', 'ABIOMED INC'],
#  ['003709 10 2', 'ABLE ENERGY'],
#  ['00371F 20 6', 'ABLEAUCTIONS COM INC'],
#  ['00371N 40 7', 'ABLE LABORATORIES INC'],
#  ['00371N 90 7', 'ABLE LABORATORIES INC'],
#  ['00371N 95 7', 'ABLE LABORATORIES INC'],
#  ['00371W 10 0', 'ABLEST INC'],
#  ['003788 10 6', 'ABRAMS INDS INC'],
#  ['003830 10 6', 'ABRAXAS PETE CORP'],
#  ['003881 20 8', 'ACACIA RESH CORP'],
#  ['003881 30 7', 'ACACIA RESH CORP'],
#  ['003881 90 7', 'ACACIA RESH CORP'],
#  ['003881 95 7',
#   'ACACIA RESH CORP',
#   'COM',
#   'NOTE  3.500% 3/1',
#   'CALL',
#   'PUT',
#   'COM NEW',
#   'COMBIMTRX  COM',
#   'ACACIA TCH COM'],
#  ['003924 10 7', 'ABITIBI-CONSOLIDATED INC', 'COM'],
#  ['003924 90 7', 'ABITIBI-CONSOLIDATED INC'],
#  ['003924 95 7', 'ABITIBI-CONSOLIDATED INC'],
#  ['004239 10 9', 'ACADIA RLTY TR'],
#  ['004286 10 0', 'ACAMBIS PLC'],
#  ['004286 90 0', 'ACAMBIS PLC'],
#  ['004286 95 0',
#   'ACAMBIS PLC',
#   'CALL',
#   'PUT',
#   'COM SH BEN INT',
#   'SPONSORED ADR'],
#  ['004304 20 0', 'ACCELR8 TECHNOLOGY CORP', 'COM NEW'],
#  ['00431F 10 5', 'ACCESS ANYTIME BANCORP', 'COM'],
#  ['00431M 20 9', 'ACCESS PHARMACEUTICALS INC', 'COM NEW'],
#  ['004325 20 5', 'ACCLAIM ENTMT INC', 'COM PAR $0.02'],
#  ['004325 90 5', 'ACCLAIM ENTMT INC'],
#  ['004325 95 5', 'ACCLAIM ENTMT INC', 'CALL', 'PUT'],
#  ['004329 10 8', 'ACCESS INTEGRATED TECHNLGS I', 'CL A'],
#  ['00433F 10 3', 'ACCESSITY CORP', 'COM', 'DELETED'],
#  ['00433F 20 2', 'ACCESSITY CORP', 'COM NEW', 'ADDED'],
#  ['00437P 10 7', 'ACCREDITED HOME LENDRS HLDG', 'COM'],
#  ['00437P 90 7', 'ACCREDITED HOME LENDRS HLDG'],
#  ['00437P 95 7', 'ACCREDITED HOME LENDRS HLDG', 'CALL', 'PUT'],
#  ['00437V 10 4', 'ACCREDO HEALTH INC', 'COM'],
#  ['00437V 90 4', 'ACCREDO HEALTH INC'],
#  ['00437V 95 4', 'ACCREDO HEALTH INC'],
#  ['004403 10 1', 'ACE CASH EXPRESS INC'],
#  ['004404 10 9', 'ACE COMM CORP'],
#  ['004446 10 0', 'ACETO CORP'],
#  ['00461P 10 6', 'ACLARA BIOSCIENCES INC'],
#  ['00461P 90 6', 'ACLARA BIOSCIENCES INC'],
#  ['00461P 95 6', 'ACLARA BIOSCIENCES INC'],
#  ['004616 20 7', 'ACMAT CORP'],
#  ['004631 10 7', 'ACME COMMUNICATION INC'],
#  ['004816 10 4', 'ACME UTD CORP'],
#  ['004920 10 4', 'ACTION PRODS INTL INC', 'CALL', 'PUT', 'COM', 'CL A'],
#  ['004930 20 2', 'ACTIVISION INC NEW', 'COM NEW'],
#  ['004930 90 2', 'ACTIVISION INC NEW'],
#  ['004930 95 2', 'ACTIVISION INC NEW', 'CALL', 'PUT'],
#  ['004933 AB 3', 'ACTION PERFORMANCE COS INC', 'NOTE  4.750% 4/0', 'DELETED'],
#  ['004933 10 7', 'ACTION PERFORMANCE COS INC', 'COM'],
#  ['004933 90 7', 'ACTION PERFORMANCE COS INC'],
#  ['004933 95 7', 'ACTION PERFORMANCE COS INC', 'CALL', 'PUT'],
#  ['004934 10 5', 'ACTEL CORP', 'COM'],
#  ['004934 90 5', 'ACTEL CORP'],
#  ['004934 95 5', 'ACTEL CORP', 'CALL', 'PUT'],
#  ['00504W 10 0', 'ACTIVE POWER INC', 'COM'],
#  ['00504W 90 0', 'ACTIVE POWER INC'],
#  ['00504W 95 0', 'ACTIVE POWER INC', 'CALL', 'PUT'],
#  ['00506J 10 7', 'ACTIVCARD CORP'],
#  ['00508B 10 2', 'ACTUATE CORP'],
#  ['00508B 90 2', 'ACTUATE CORP'],
#  ['00508B 95 2', 'ACTUATE CORP'],
#  ['00508X 20 3', 'ACTUANT CORP'],
#  ['00508Y 10 2', 'ACUITY BRANDS INC'],
#  ['00508Y 90 2', 'ACUITY BRANDS INC'],
#  ['00508Y 95 2', 'ACUITY BRANDS INC'],
#  ['00511R 87 0', 'ACUSPHERE INC'],
#  ['005125 AB 5', 'ACXIOM CORP'],
#  ['005125 10 9', 'ACXIOM CORP'],
#  ['005125 90 9', 'ACXIOM CORP'],
#  ['005125 95 9', 'ACXIOM CORP'],
#  ['006212 10 4', 'ADAMS EXPRESS CO'],
#  ['006351 30 8', 'ADAMS RES & ENERGY INC'],
#  ['00651F AE 8', 'ADAPTEC INC'],
#  ['00651F 10 8', 'ADAPTEC INC'],
#  ['00651F 90 8', 'ADAPTEC INC'],
#  ['00651F 95 8',
#   'ADAPTEC INC',
#   'COM',
#   'CALL',
#   'PUT',
#   'CL A NEW',
#   'NOTE  3.750% 2/1',
#   'COM NEW',
#   'NOTE  3.000% 3/0'],
#  ['006743 30 6', 'ADDVANTAGE TECHNOLOGIES GP I', 'COM NEW'],
#  ['006754 10 5', 'ADECCO SA'],
#  ['00709P 10 8', 'ADMINISTRADORA FONDOS PENSIO'],
#  ['007094 10 5', 'ADMINISTAFF INC'],
#  ['007094 90 5', 'ADMINISTAFF INC'],
#  ['007094 95 5', 'ADMINISTAFF INC', 'SPONSORED ADR', 'COM', 'CALL', 'PUT'],
#  ['00724F 10 1', 'ADOBE SYS INC', 'COM'],
#  ['00724F 90 1', 'ADOBE SYS INC'],
#  ['00724F 95 1', 'ADOBE SYS INC', 'CALL', 'PUT'],
#  ['00724X 10 2', 'ADOLOR CORP', 'COM'],
#  ['00724X 90 2', 'ADOLOR CORP'],
#  ['00724X 95 2', 'ADOLOR CORP'],
#  ['00737P 10 4', 'ADSTAR INC'],
#  ['00737P 11 2', 'ADSTAR INC'],
#  ['00738A 10 6', 'ADTRAN INC', 'CALL', 'PUT', 'COM', '*W EXP 12/16/200'],
#  ['00738A 90 6', 'ADTRAN INC'],
#  ['00738A 95 6', 'ADTRAN INC'],
#  ['007437 10 6', 'ADVANCE FINL BANCORP'],
#  ['00751Y 10 6', 'ADVANCE AUTO PARTS INC'],
#  ['00751Y 90 6', 'ADVANCE AUTO PARTS INC'],
#  ['00751Y 95 6', 'ADVANCE AUTO PARTS INC', 'CALL', 'PUT', 'COM'],
#  ['007525 10 8', 'ADVANCED DIGITAL INFORMATION', 'COM'],
#  ['007525 90 8', 'ADVANCED DIGITAL INFORMATION'],
#  ['007525 95 8', 'ADVANCED DIGITAL INFORMATION', 'CALL', 'PUT'],
#  ['00753P 10 3', 'ADVANCED MAGNETICS INC'],
#  ['00753T 10 5', 'ADVANCED MARKETING SVCS INC', 'COM'],
#  ['00754A 10 5', 'ADVANCED FIBRE COMMUNICATION', 'COM'],
#  ['00754A 90 5', 'ADVANCED FIBRE COMMUNICATION'],
#  ['00754A 95 5', 'ADVANCED FIBRE COMMUNICATION', 'CALL', 'PUT'],
#  ['00754E 10 7', 'ADVANCED PHOTONIX INC', 'CL A'],
#  ['00756G 15 9', 'ADVANTAGE MARKETING SYSTEMS', '*W EXP 11/12/200', 'DELETED'],
#  ['00756G 16 7', 'ADVANTAGE MARKETING SYSTEMS', '*W EXP 11/12/200', 'DELETED'],
#  ['00756G 20 9', 'ADVANTAGE MARKETING SYSTEMS', 'COM NEW'],
#  ['00756M 40 4', 'ADVANCED SEMICONDUCTOR ENGR', 'SPONSORED ADR'],
#  ['00757T 10 1', 'ADVANCED NEUROMODULATION SYS', 'COM'],
#  ['00757T 90 1', 'ADVANCED NEUROMODULATION SYS'],
#  ['00757T 95 1', 'ADVANCED NEUROMODULATION SYS', 'CALL', 'PUT'],
#  ['007585 10 2', 'ADVO INC', 'COM'],
#  ['007585 90 2', 'ADVO INC'],
#  ['007585 95 2', 'ADVO INC'],
#  ['00760J 10 8', 'AEHR TEST SYSTEMS'],
#  ['00761E 10 8', 'ADVANCED POWER TECHNOLOGY IN'],
#  ['00762U 10 1', 'ADVANTEST CORP'],
#  ['00762W 10 7', 'ADVISORY BRD CO', 'CALL', 'PUT', 'COM', 'SPONSORED ADR'],
#  ['00763M AE 8', 'ADVANCED MEDICAL OPTICS INC', 'NOTE  3.500% 4/1'],
#  ['00763M 10 8', 'ADVANCED MEDICAL OPTICS INC', 'COM'],
#  ['00763M 90 8', 'ADVANCED MEDICAL OPTICS INC'],
#  ['00763M 95 8', 'ADVANCED MEDICAL OPTICS INC', 'CALL', 'PUT'],
#  ['00764C 10 9', 'ADVENT CLAYMORE CV SECS & IN', 'COM'],
#  ['00764L 10 9', 'ADVANCIS PHARMACEUTICALS COR', 'COM'],
#  ['007692 10 6', 'AERO SYS ENGR INC', 'COM', 'DELETED'],
#  ['007737 10 9', 'AEROCENTURY CORP'],
#  ['007768 10 4', 'AEROFLEX INC'],
#  ['007768 90 4', 'AEROFLEX INC'],
#  ['007768 95 4', 'AEROFLEX INC'],
#  ['007779 30 9', 'AEROGEN INC'],
#  ['007865 10 8', 'AEROPOSTALE'],
#  ['007865 90 8', 'AEROPOSTALE'],
#  ['007865 95 8', 'AEROPOSTALE', 'COM', 'CALL', 'PUT', 'COM NEW'],
#  ['00790K 10 9', 'ADVANCEPCS', 'COM'],
#  ['00790K 90 9', 'ADVANCEPCS'],
#  ['00790K 95 9', 'ADVANCEPCS', 'CALL', 'PUT'],
#  ['007903 AE 7', 'ADVANCED MICRO DEVICES INC', 'DBCV  4.750% 2/0'],
#  ['007903 AF 4', 'ADVANCED MICRO DEVICES INC', 'NOTE  4.500%12/0'],
#  ['007903 10 7', 'ADVANCED MICRO DEVICES INC', 'COM'],
#  ['007903 90 7', 'ADVANCED MICRO DEVICES INC'],
#  ['007903 95 7', 'ADVANCED MICRO DEVICES INC', 'CALL', 'PUT'],
#  ['007924 10 3', 'AEGON N V', 'ORD AMER REG'],
#  ['007924 90 3', 'AEGON N V'],
#  ['007924 95 3', 'AEGON N V', 'CALL', 'PUT'],
#  ['007942 10 5', 'ADVANTA CORP', 'CL A'],
#  ['007942 90 5', 'ADVANTA CORP'],
#  ['007942 95 5', 'ADVANTA CORP', 'CALL', 'PUT'],
#  ['007942 20 4', 'ADVANTA CORP', 'CL B'],
#  ['007942 90 4', 'ADVANTA CORP'],
#  ['007942 95 4', 'ADVANTA CORP', 'CALL', 'PUT'],
#  ['007947 10 4', 'ADVANCED ENVIRON RECYCLING T', 'CL A'],
#  ['007973 AA 8', 'ADVANCED ENERGY INDS'],
#  ['007973 AC 4',
#   'ADVANCED ENERGY INDS',
#   'NOTE  5.250%11/1',
#   'NOTE  5.000% 9/0'],
#  ['007973 10 0', 'ADVANCED ENERGY INDS', 'COM'],
#  ['007973 90 0', 'ADVANCED ENERGY INDS'],
#  ['007973 95 0', 'ADVANCED ENERGY INDS', 'CALL', 'PUT'],
#  ['007974 10 8', 'ADVENT SOFTWARE INC', 'COM'],
#  ['007974 90 8', 'ADVENT SOFTWARE INC'],
#  ['007974 95 8', 'ADVENT SOFTWARE INC', 'CALL', 'PUT'],
#  ['007975 10 5', 'AETERNA LABORATORIES INC', 'SUB VTG SH'],
#  ['007975 90 5', 'AETERNA LABORATORIES INC'],
#  ['007975 95 5', 'AETERNA LABORATORIES INC'],
#  ['008015 30 7', 'AEROSONIC CORP DEL'],
#  ['00808N 20 2', 'AES TR III'],
#  ['00808V AA 3', 'AETHER SYS INC'],
#  ['00808V 10 5', 'AETHER SYS INC'],
#  ['00808V 90 5', 'AETHER SYS INC'],
#  ['00808V 95 5', 'AETHER SYS INC'],
#  ['00817R 10 3', 'AETRIUM INC'],
#  ['00817Y 10 8', 'AETNA INC NEW'],
#  ['00817Y 90 8', 'AETNA INC NEW'],
#  ['00817Y 95 8',
#   'AETNA INC NEW',
#   'CALL',
#   'PUT',
#   'COM PAR $0.40',
#   'PFD CV 6.75%',
#   'NOTE  6.000% 3/2',
#   'COM'],
#  ['008190 AF 7',
#   'AFFILIATED COMPUTER SERVICES',
#   'NOTE  3.500% 2/1',
#   'DELETED'],
#  ['008190 10 0', 'AFFILIATED COMPUTER SERVICES', 'CL A'],
#  ['008190 90 0', 'AFFILIATED COMPUTER SERVICES'],
#  ['008190 95 0', 'AFFILIATED COMPUTER SERVICES', 'CALL', 'PUT'],
#  ['008252 AC 2', 'AFFILIATED MANAGERS GROUP', 'NOTE         5/0'],
#  ['008252 AE 8', 'AFFILIATED MANAGERS GROUP', 'DBCV         2/2', 'ADDED'],
#  ['008252 10 8', 'AFFILIATED MANAGERS GROUP', 'COM'],
#  ['008252 90 8', 'AFFILIATED MANAGERS GROUP'],
#  ['008252 95 8', 'AFFILIATED MANAGERS GROUP', 'CALL', 'PUT'],
#  ['00826T AB 4', 'AFFYMETRIX INC', 'NOTE  5.000%10/0', 'DELETED'],
#  ['00826T AD 0', 'AFFYMETRIX INC', 'NOTE  4.750% 2/1', 'DELETED'],
#  ['00826T 10 8', 'AFFYMETRIX INC', 'COM'],
#  ['00826T 90 8', 'AFFYMETRIX INC'],
#  ['00826T 95 8', 'AFFYMETRIX INC', 'CALL', 'PUT'],
#  ['008273 10 4', 'AFFORDABLE RESIDENTIAL CMTYS', 'COM', 'ADDED'],
#  ['008318 10 7', 'AFTERMARKET TECHNOLOGY CORP', 'COM'],
#  ['008318 90 7', 'AFTERMARKET TECHNOLOGY CORP'],
#  ['008318 95 7', 'AFTERMARKET TECHNOLOGY CORP', 'CALL', 'PUT'],
#  ['00845V AA 8', 'AGERE SYS INC', 'NOTE  6.500%12/1'],
#  ['00845V 10 0', 'AGERE SYS INC', 'CL A'],
#  ['00845V 90 0', 'AGERE SYS INC'],
#  ['00845V 95 0', 'AGERE SYS INC', 'CALL', 'PUT'],
#  ['00845V 20 9', 'AGERE SYS INC', 'CL B'],
#  ['00845V 90 9', 'AGERE SYS INC'],
#  ['00845V 95 9', 'AGERE SYS INC', 'CALL', 'PUT'],
#  ['00846U AB 7', 'AGILENT TECHNOLOGIES INC', 'DBCV  3.000%12/0'],
#  ['00846U 10 1', 'AGILENT TECHNOLOGIES INC', 'COM'],
#  ['00846U 90 1', 'AGILENT TECHNOLOGIES INC'],
#  ['00846U 95 1', 'AGILENT TECHNOLOGIES INC', 'CALL', 'PUT'],
#  ['00846X 10 5', 'AGILE SOFTWARE CORP DEL', 'COM'],
#  ['00846X 90 5', 'AGILE SOFTWARE CORP DEL'],
#  ['00846X 95 5', 'AGILE SOFTWARE CORP DEL', 'CALL', 'PUT'],
#  ['00847J 10 5', 'AGILYSYS INC', 'COM'],
#  ['00847J 90 5', 'AGILYSYS INC'],
#  ['00847J 95 5', 'AGILYSYS INC', 'CALL', 'PUT'],
#  ['008474 AB 4', 'AGNICO EAGLE MINES LTD', 'SDCV  4.500% 2/1'],
#  ['008474 10 8', 'AGNICO EAGLE MINES LTD', 'COM'],
#  ['008474 90 8', 'AGNICO EAGLE MINES LTD'],
#  ['008474 95 8', 'AGNICO EAGLE MINES LTD', 'CALL', 'PUT'],
#  ['008474 13 2', 'AGNICO EAGLE MINES LTD', '*W EXP 11/07/200'],
#  ['008492 10 0', 'AGREE REALTY CORP'],
#  ['00888R 10 7', 'AIM SELECT REAL ESTATE INCM'],
#  ['008916 10 8', 'AGRIUM INC'],
#  ['008916 90 8', 'AGRIUM INC'],
#  ['008916 95 8', 'AGRIUM INC', 'COM', 'SHS', 'CALL', 'PUT'],
#  ['009128 30 7', 'AIR METHODS CORP', 'COM PAR $.06'],
#  ['009128 90 7', 'AIR METHODS CORP'],
#  ['009128 95 7', 'AIR METHODS CORP', 'CALL', 'PUT'],
#  ['009158 10 6', 'AIR PRODS & CHEMS INC', 'COM'],
#  ['009158 90 6', 'AIR PRODS & CHEMS INC'],
#  ['009158 95 6', 'AIR PRODS & CHEMS INC'],
#  ['009207 10 1', 'AIR T INC'],
#  ['009363 10 2', 'AIRGAS INC', 'CALL', 'PUT', 'COM'],
#  ['009363 90 2', 'AIRGAS INC'],
#  ['009363 95 2', 'AIRGAS INC', 'CALL', 'PUT'],
#  ['009367 30 1', 'AIRGATE PCS INC', 'COM NEW', 'ADDED'],
#  ['00941P 10 6', 'AIRNET COMMUNICATIONS CORP', 'COM'],
#  ['00941P 90 6', 'AIRNET COMMUNICATIONS CORP'],
#  ['00941P 95 6', 'AIRNET COMMUNICATIONS CORP', 'CALL', 'PUT'],
#  ['009417 10 6', 'AIRNET SYS INC'],
#  ['00949P AB 4', 'AIRTRAN HLDGS INC'],
#  ['00949P 10 8', 'AIRTRAN HLDGS INC'],
#  ['00949P 90 8', 'AIRTRAN HLDGS INC'],
#  ['00949P 95 8',
#   'AIRTRAN HLDGS INC',
#   'COM',
#   'NOTE  7.000% 7/0',
#   'CALL',
#   'PUT'],
#  ['00950H 10 2', 'AIRSPAN NETWORKS INC', 'COM'],
#  ['00971T AC 5', 'AKAMAI TECHNOLOGIES INC', 'NOTE  5.500% 7/0'],
#  ['00971T 10 1', 'AKAMAI TECHNOLOGIES INC', 'COM'],
#  ['00971T 90 1', 'AKAMAI TECHNOLOGIES INC'],
#  ['00971T 95 1', 'AKAMAI TECHNOLOGIES INC', 'CALL', 'PUT'],
#  ['010196 10 3', 'AKSYS LTD', 'COM'],
#  ['010196 90 3', 'AKSYS LTD'],
#  ['010196 95 3', 'AKSYS LTD'],
#  ['010198 20 8', 'AKTIEBOLAGETT ELECTROLUX'],
#  ['010199 30 5', 'AKZO NOBEL NV'],
#  ['010199 90 5', 'AKZO NOBEL NV'],
#  ['010199 95 5', 'AKZO NOBEL NV'],
#  ['010317 10 5', 'ALABAMA NATL BANCORP DELA'],
#  ['011311 10 7', 'ALAMO GROUP INC', 'CALL', 'PUT', 'SPONSORED ADR', 'COM'],
#  ['011589 10 8', 'ALAMOSA HLDGS INC', 'COM', 'ADDED'],
#  ['011612 40 5', 'ALANCO TECHNOLOGIES INC'],
#  ['011637 10 5', 'ALARIS MEDICAL SYSTEMS INC'],
#  ['011659 AG 4', 'ALASKA AIR GROUP INC'],
#  ['011659 10 9', 'ALASKA AIR GROUP INC'],
#  ['011659 90 9', 'ALASKA AIR GROUP INC'],
#  ['011659 95 9', 'ALASKA AIR GROUP INC'],
#  ['01167P 10 1', 'ALASKA COMMUNICATIONS SYS GR'],
#  ['012348 10 8',
#   'ALBANY INTL CORP',
#   'COM NO PAR NEW',
#   'COM',
#   'DBCV         3/2',
#   'CALL',
#   'PUT',
#   'CL A'],
#  ['012423 10 9', 'ALBANY MOLECULAR RESH INC', 'COM'],
#  ['012423 90 9', 'ALBANY MOLECULAR RESH INC'],
#  ['012423 95 9', 'ALBANY MOLECULAR RESH INC', 'CALL', 'PUT'],
#  ['012653 10 1', 'ALBEMARLE CORP', 'COM'],
#  ['012653 90 1', 'ALBEMARLE CORP'],
#  ['012653 95 1', 'ALBEMARLE CORP', 'CALL', 'PUT'],
#  ['012684 10 6', 'ALBEMARLE FIRST BK VA', 'COM'],
#  ['012684 11 4', 'ALBEMARLE FIRST BK VA', '*W EXP 10/26/200'],
#  ['013068 10 1', 'ALBERTO CULVER CO', 'COM'],
#  ['013068 90 1', 'ALBERTO CULVER CO'],
#  ['013068 95 1', 'ALBERTO CULVER CO', 'CALL', 'PUT'],
#  ['013104 10 4', 'ALBERTSONS INC', 'COM'],
#  ['013104 90 4', 'ALBERTSONS INC'],
#  ['013104 95 4', 'ALBERTSONS INC', 'CALL', 'PUT'],
#  ['013716 10 5', 'ALCAN INC', 'COM'],
#  ['013716 90 5', 'ALCAN INC'],
#  ['013716 95 5', 'ALCAN INC'],
#  ['013742 50 7', 'ALCIDE CORP'],
#  ['013817 10 1', 'ALCOA INC'],
#  ['013817 90 1', 'ALCOA INC'],
#  ['013817 95 1', 'ALCOA INC'],
#  ['013896 10 5', 'ALCON LABS INC'],
#  ['013904 30 5', 'ALCATEL'],
#  ['013904 90 5', 'ALCATEL'],
#  ['013904 95 5', 'ALCATEL', 'CALL', 'PUT', 'COM NEW', 'COM', 'SPONSORED ADR'],
#  ['014383 10 3', 'ALDERWOODS GROUP INC', 'COM'],
#  ['014383 11 1', 'ALDERWOODS GROUP INC'],
#  ['014384 20 0', 'ALDILA INC', '*W EXP 01/02/200', 'COM NEW'],
#  ['014482 10 3', 'ALEXANDER & BALDWIN INC', 'COM'],
#  ['014482 90 3', 'ALEXANDER & BALDWIN INC'],
#  ['014482 95 3', 'ALEXANDER & BALDWIN INC'],
#  ['014752 10 9', 'ALEXANDERS INC'],
#  ['015271 10 9', 'ALEXANDRIA REAL ESTATE EQ IN', 'CALL', 'PUT', 'COM'],
#  ['015351 AB 5', 'ALEXION PHARMACEUTICALS INC', 'NOTE  5.750% 3/1'],
#  ['015351 10 9', 'ALEXION PHARMACEUTICALS INC', 'COM'],
#  ['015351 90 9', 'ALEXION PHARMACEUTICALS INC'],
#  ['015351 95 9', 'ALEXION PHARMACEUTICALS INC', 'CALL', 'PUT'],
#  ['015385 10 7', 'ALFA CORP'],
#  ['016230 10 4', 'ALICO INC'],
#  ['016255 10 1', 'ALIGN TECHNOLOGY INC'],
#  ['016255 90 1', 'ALIGN TECHNOLOGY INC'],
#  ['016255 95 1', 'ALIGN TECHNOLOGY INC', 'COM', 'CALL', 'PUT'],
#  ['01642T AB 4', 'ALKERMES INC', 'NOTE  3.750% 2/1', 'DELETED'],
#  ['01642T AE 8', 'ALKERMES INC'],
#  ['01642T 10 8', 'ALKERMES INC'],
#  ['01642T 90 8', 'ALKERMES INC'],
#  ['01642T 95 8', 'ALKERMES INC', 'NOTE  2.500% 9/0', 'COM', 'CALL', 'PUT'],
#  ['016557 40 7', 'ALL AMERICAN SEMICONDUCTOR I', 'COM NEW'],
#  ['017175 10 0', 'ALLEGHANY CORP DEL'],
#  ['017361 10 6', 'ALLEGHENY ENERGY INC'],
#  ['017361 90 6', 'ALLEGHENY ENERGY INC'],
#  ['017361 95 6', 'ALLEGHENY ENERGY INC', 'COM', 'CALL', 'PUT'],
#  ['01741R 10 2', 'ALLEGHENY TECHNOLOGIES INC', 'COM'],
#  ['01741R 90 2', 'ALLEGHENY TECHNOLOGIES INC'],
#  ['01741R 95 2', 'ALLEGHENY TECHNOLOGIES INC', 'CALL', 'PUT'],
#  ['017476 10 2', 'ALLEGIANT BANCORP INC'],
#  ['017753 10 4', 'ALLEN ORGAN CO'],
#  ['018490 AE 2', 'ALLERGAN INC'],
#  ['018490 10 2', 'ALLERGAN INC'],
#  ['018490 90 2', 'ALLERGAN INC'],
#  ['018490 95 2', 'ALLERGAN INC'],
#  ['01852M 10 8', 'ALLIANCE ALL MARKET ADVANTAG'],
#  ['01852Q 10 9', 'ALLIANCE BANCORP NEW ENG INC'],
#  ['018522 10 2', 'ALLETE INC'],
#  ['018522 90 2', 'ALLETE INC'],
#  ['018522 95 2',
#   'ALLETE INC',
#   'COM',
#   'CL B',
#   'NOTE        11/0',
#   'CALL',
#   'PUT'],
#  ['01853E 20 4', 'ALLIANCE ATLANTIS COMMUNICAT', 'CL B NON-VTG'],
#  ['018535 10 4', 'ALLIANCE BANKSHARES CORP', 'COM'],
#  ['018546 10 1', 'ALLIANCE CALIF MUN INCOME FD'],
#  ['01855A 10 1', 'ALLIANCE CAP MGMT HLDG L P'],
#  ['01855A 90 1', 'ALLIANCE CAP MGMT HLDG L P'],
#  ['01855A 95 1',
#   'ALLIANCE CAP MGMT HLDG L P',
#   'COM',
#   'UNIT LTD PARTN',
#   'CALL',
#   'PUT'],
#  ['018581 10 8', 'ALLIANCE DATA SYSTEMS CORP', 'COM'],
#  ['018581 90 8', 'ALLIANCE DATA SYSTEMS CORP'],
#  ['018581 95 8', 'ALLIANCE DATA SYSTEMS CORP', 'CALL', 'PUT'],
#  ['01859P 60 9', 'ALLIANCE GAMING CORP', 'COM NEW'],
#  ['01859P 90 9', 'ALLIANCE GAMING CORP'],
#  ['01859P 95 9', 'ALLIANCE GAMING CORP', 'CALL', 'PUT'],
#  ['018606 20 2', 'ALLIANCE IMAGING INC', 'COM NEW'],
#  ['01864U 10 6', 'ALLIANCE NATL MUN INCOME FD'],
#  ['018680 10 8', 'ALLIANCE FIBER OPTIC PRODS I'],
#  ['018714 10 5', 'ALLIANCE NEW YORK MUN INC FD'],
#  ['01877H 10 0', 'ALLIANCE SEMICONDUCTOR CORP', 'COM'],
#  ['01877H 90 0', 'ALLIANCE SEMICONDUCTOR CORP'],
#  ['01877H 95 0', 'ALLIANCE SEMICONDUCTOR CORP', 'CALL', 'PUT'],
#  ['01877R 10 8', 'ALLIANCE RES PARTNER L P', 'UT LTD PART'],
#  ['01879R 10 6', 'ALLIANCE WORLD DLR GV FD II'],
#  ['018796 10 2', 'ALLIANCE WORLD DLR GV FD INC'],
#  ['018802 10 8', 'ALLIANT ENERGY CORP'],
#  ['018802 90 8', 'ALLIANT ENERGY CORP'],
#  ['018802 95 8', 'ALLIANT ENERGY CORP', 'COM', 'CALL', 'PUT'],
#  ['018804 10 4', 'ALLIANT TECHSYSTEMS INC', 'COM'],
#  ['018804 90 4', 'ALLIANT TECHSYSTEMS INC'],
#  ['018804 95 4', 'ALLIANT TECHSYSTEMS INC', 'CALL', 'PUT'],
#  ['018805 10 1', 'ALLIANZ AKTIENGESELLSCHAFT', 'SP ADR 1/10 SH'],
#  ['01903Q 10 8', 'ALLIED CAP CORP NEW', 'COM'],
#  ['01903Q 90 8', 'ALLIED CAP CORP NEW'],
#  ['01903Q 95 8', 'ALLIED CAP CORP NEW'],
#  ['019118 10 8', 'ALLIED DEFENSE GROUP INC'],
#  ['019121 20 1', 'ALLIED DOMECQ PLC'],
#  ['019205 10 3', 'ALLIANCE FINANCIAL CORP NY'],
#  ['019222 10 8',
#   'ALLIED HEALTHCARE PRODS INC',
#   'CALL',
#   'PUT',
#   'COM',
#   'SPON ADR NEW'],
#  ['019223 10 6', 'ALLIED HLDGS INC', 'COM'],
#  ['019228 40 2', 'ALLIED IRISH BKS P L C', 'SPON ADR ORD'],
#  ['019228 90 2', 'ALLIED IRISH BKS P L C'],
#  ['019228 95 2', 'ALLIED IRISH BKS P L C'],
#  ['01923A 10 9', 'ALLIED HEALTHCARE INTL INC'],
#  ['019330 10 9', 'ALLIED MOTION TECHNOLOGIES I', 'CALL', 'PUT', 'COM'],
#  ['019496 AB 4', 'ALLIED RISER COMMUNICATIONS', 'NOTE  7.500% 6/1', 'DELETED'],
#  ['019589 30 8', 'ALLIED WASTE INDS INC', 'COM PAR$.01NEW'],
#  ['019589 90 8', 'ALLIED WASTE INDS INC'],
#  ['019589 95 8', 'ALLIED WASTE INDS INC', 'CALL', 'PUT'],
#  ['019589 60 5', 'ALLIED WASTE INDS INC', 'PFD SR C  CONV'],
#  ['019754 10 0', 'ALLMERICA FINL CORP', 'COM'],
#  ['019754 90 0', 'ALLMERICA FINL CORP'],
#  ['019754 95 0', 'ALLMERICA FINL CORP', 'CALL', 'PUT'],
#  ['019777 10 1', 'ALLOS THERAPEUTICS INC', 'COM'],
#  ['019777 90 1', 'ALLOS THERAPEUTICS INC'],
#  ['019777 95 1', 'ALLOS THERAPEUTICS INC', 'CALL', 'PUT'],
#  ['019855 10 5', 'ALLOY INC', 'COM'],
#  ['019855 90 5', 'ALLOY INC'],
#  ['019855 95 5', 'ALLOY INC', 'CALL', 'PUT'],
#  ['01988P 10 8', 'ALLSCRIPTS HEALTHCARE SOLUTI', 'COM'],
#  ['01988P 90 8', 'ALLSCRIPTS HEALTHCARE SOLUTI'],
#  ['01988P 95 8', 'ALLSCRIPTS HEALTHCARE SOLUTI', 'CALL', 'PUT'],
#  ['019921 10 5', 'ALLMERICA SECS TR'],
#  ['020002 10 1', 'ALLSTATE CORP'],
#  ['020002 90 1', 'ALLSTATE CORP'],
#  ['020002 95 1', 'ALLSTATE CORP', 'SH BEN INT', 'COM', 'CALL', 'PUT'],
#  ['020039 10 3', 'ALLTEL CORP', 'COM'],
#  ['020039 90 3', 'ALLTEL CORP'],
#  ['020039 95 3', 'ALLTEL CORP'],
#  ['020039 50 9', 'ALLTEL CORP'],
#  ['020039 82 2', 'ALLTEL CORP'],
#  ['02004C 10 5', 'ALLSTREAM INC'],
#  ['02004C 20 4',
#   'ALLSTREAM INC',
#   'CALL',
#   'PUT',
#   'PFD C CV $2.06',
#   'CORP UNT 7.75%',
#   'CL A VTG SHS',
#   'CL B LT VTG SH'],
#  ['020409 10 8', 'ALMOST FAMILY INC'],
#  ['020772 10 9', 'ALPHA PRO TECH LTD'],
#  ['020781 10 0', 'ALPHA TECHNOLOGIES GROUP INC', 'COM'],
#  ['02081F 10 4', 'ALPHASMART INC', 'COM', 'ADDED'],
#  ['020813 AB 7', 'ALPHARMA INC'],
#  ['020813 AC 5', 'ALPHARMA INC'],
#  ['020813 AD 3', 'ALPHARMA INC'],
#  ['020813 10 1', 'ALPHARMA INC'],
#  ['020813 90 1', 'ALPHARMA INC'],
#  ['020813 95 1', 'ALPHARMA INC'],
#  ['021244 10 8', 'ALSTOM'],
#  ['021373 10 5', 'ALTAIR NANOTECHNOLOGIES INC'],
#  ['02143N 10 3', 'ALTANA AKTIENGESELLSCHAFT'],
#  ['02144G 10 7', 'ALTEON INC'],
#  ['021441 10 0', 'ALTERA CORP'],
#  ['021441 90 0', 'ALTERA CORP'],
#  ['021441 95 0',
#   'ALTERA CORP',
#   'NOTE  5.750% 4/0',
#   'NOTE  3.000% 6/0',
#   'CL A',
#   'CALL',
#   'PUT',
#   'SPONSORED ADR',
#   'COM'],
#  ['02148M 10 0', 'ALTIRIS INC', 'COM'],
#  ['02148M 90 0', 'ALTIRIS INC'],
#  ['02148M 95 0', 'ALTIRIS INC'],
#  ['021489 10 9', 'ALTIGEN COMMUNICATIONS INC'],
#  ['02151P 10 7', 'ALTO PALERMO S A'],
#  ['02209S 10 3', 'ALTRIA GROUP INC'],
#  ['02209S 90 3', 'ALTRIA GROUP INC'],
#  ['02209S 95 3', 'ALTRIA GROUP INC'],
#  ['022205 10 8', 'ALUMINA LTD'],
#  ['022276 10 9', 'ALUMINUM CORP CHINA LTD'],
#  ['022276 90 9', 'ALUMINUM CORP CHINA LTD'],
#  ['022276 95 9', 'ALUMINUM CORP CHINA LTD'],
#  ['02261W AB 5', 'ALZA CORP'],
#  ['022615 AC 2', 'ALZA CORP DEL'],
#  ['023111 10 7', 'AMARIN CORP PLC'],
#  ['023135 AE 6', 'AMAZON COM INC'],
#  ['023135 AF 3',
#   'AMAZON COM INC',
#   'CALL',
#   'PUT',
#   'COM',
#   'SPONSORED ADR',
#   'SPON ADR H SHS',
#   'SDCV         7/2',
#   'NOTE         7/1',
#   'NOTE  4.750% 2/0'],
#  ['023135 10 6', 'AMAZON COM INC', 'COM'],
#  ['023135 90 6', 'AMAZON COM INC'],
#  ['023135 95 6', 'AMAZON COM INC', 'CALL', 'PUT'],
#  ['023139 10 8', 'AMBAC FINL GROUP INC', 'COM'],
#  ['023139 90 8', 'AMBAC FINL GROUP INC'],
#  ['023139 95 8', 'AMBAC FINL GROUP INC'],
#  ['023177 10 8', 'AMBASSADORS GROUP INC'],
#  ['023178 10 6', 'AMBASSADORS INTL INC'],
#  ['02341Q 10 6', 'AMCON DISTRG CO'],
#  ['02341R 30 2', 'AMCOR LTD'],
#  ['02341R 40 1', 'AMCOR LTD'],
#  ['02341W 10 3', 'AMCOL INTL CORP'],
#  ['02341W 90 3', 'AMCOL INTL CORP'],
#  ['02341W 95 3', 'AMCOL INTL CORP'],
#  ['02342T AB 5', 'AMDOCS LTD'],
#  ['023436 10 8', 'AMEDISYS INC'],
#  ['023477 20 1', 'AMEN PPTYS INC'],
#  ['023551 10 4', 'AMERADA HESS CORP'],
#  ['023551 90 4', 'AMERADA HESS CORP'],
#  ['023551 95 4',
#   'AMERADA HESS CORP',
#   'CALL',
#   'PUT',
#   'COM',
#   'ADR NEW',
#   'PRIDES 7.25%',
#   'NOTE  2.000% 6/0',
#   'COM NEW'],
#  ['023551 40 1', 'AMERADA HESS CORP', 'PFD CV ACES 7%'],
#  ['023586 10 0', 'AMERCO'],
#  ['023608 10 2', 'AMEREN CORP'],
#  ['023608 90 2', 'AMEREN CORP'],
#  ['023608 95 2', 'AMEREN CORP', 'COM', 'CALL', 'PUT'],
#  ['023608 20 1', 'AMEREN CORP', 'EQTY UN 9.75%', 'ADDED'],
#  ['023613 10 2', 'AMERIANA BANCORP'],
#  ['02363X 10 4', 'AMERICA FIRST APT INV INC'],
#  ['02364J AC 8', 'AMERICA ONLINE INC DEL'],
#  ['02364L 10 9', 'AMERICA SVC GROUP INC', 'COM', 'NOTE        12/0'],
#  ['02364V 10 7', 'AMERICA FIRST TAX EX IVS L P', 'BEN UNIT CTF'],
#  ['02364W 10 5', 'AMERICA MOVIL S A DE C V', 'SPON ADR L SHS'],
#  ['02364W 90 5', 'AMERICA MOVIL S A DE C V'],
#  ['02364W 95 5', 'AMERICA MOVIL S A DE C V', 'CALL', 'PUT'],
#  ['02364W 20 4', 'AMERICA MOVIL S A DE C V'],
#  ['02364Y 10 1', 'AMERICA FIRST REAL ESTATE IN'],
#  ['02365B 10 0', 'AMERICA ONLINE LATIN AMERICA'],
#  ['02365B 90 0', 'AMERICA ONLINE LATIN AMERICA'],
#  ['02365B 95 0',
#   'AMERICA ONLINE LATIN AMERICA',
#   'SPON ADR A SHS',
#   'UNIT LTD PARTN',
#   'CL A',
#   'CALL',
#   'PUT'],
#  ['023657 20 8', 'AMERICA WEST HLDG CORP', 'CL B'],
#  ['023657 90 8', 'AMERICA WEST HLDG CORP'],
#  ['023657 95 8', 'AMERICA WEST HLDG CORP'],
#  ['02368F 10 8', 'AMERICAN ACCES TECHNOLOGIES'],
#  ['023912 10 8', 'AMCORE FINL INC'],
#  ['023912 90 8', 'AMCORE FINL INC'],
#  ['023912 95 8', 'AMCORE FINL INC', 'CALL', 'PUT', 'COM'],
#  ['024061 10 3', 'AMERICAN AXLE & MFG HLDGS IN', 'COM'],
#  ['024061 90 3', 'AMERICAN AXLE & MFG HLDGS IN'],
#  ['024061 95 3', 'AMERICAN AXLE & MFG HLDGS IN', 'CALL', 'PUT'],
#  ['024343 10 5', 'AMERICAN BANK INC PA'],
#  ['024591 10 9', 'AMERICAN BILTRITE INC'],
#  ['024600 10 8', 'AMER BIO MEDICA CORP', 'COM'],
#  ['024600 11 6', 'AMER BIO MEDICA CORP', '*W EXP 08/22/200'],
#  ['024750 10 1', 'AMERICAN BLDG CTL INC'],
#  ['02476B 10 6', 'AMERICAN BUSINESS FINL SVCS'],
#  ['024937 10 4', 'AMERICAN CAPITAL STRATEGIES'],
#  ['024937 90 4', 'AMERICAN CAPITAL STRATEGIES'],
#  ['024937 95 4', 'AMERICAN CAPITAL STRATEGIES'],
#  ['025105 10 7', 'AMERICAN CHAIN & CABLE INC'],
#  ['025144 10 6', 'AMERICAN CLAIMS EVALUATION I'],
#  ['02520N 10 6', 'AMERICAN CMNTY PPTYS TR'],
#  ['02520W 10 6', 'AMERICAN CMNTY BANCSHARES IN', 'COM', 'CALL', 'PUT'],
#  ['02520W 11 4', 'AMERICAN CMNTY BANCSHARES IN', '*W EXP 04/30/200'],
#  ['025353 10 3', 'AMERICAN DENTAL PARTNERS'],
#  ['02553E 10 6', 'AMERICAN EAGLE OUTFITTERS NE'],
#  ['02553E 90 6', 'AMERICAN EAGLE OUTFITTERS NE'],
#  ['02553E 95 6', 'AMERICAN EAGLE OUTFITTERS NE', 'COM', 'CALL', 'PUT'],
#  ['025533 40 7', 'AMERICAN ECOLOGY CORP', 'COM NEW'],
#  ['025537 10 1', 'AMERICAN ELEC PWR INC', 'COM'],
#  ['025537 90 1', 'AMERICAN ELEC PWR INC'],
#  ['025537 95 1', 'AMERICAN ELEC PWR INC'],
#  ['025676 20 6', 'AMERICAN EQTY INVT LIFE HLD'],
#  ['025816 10 9', 'AMERICAN EXPRESS CO'],
#  ['025816 90 9', 'AMERICAN EXPRESS CO'],
#  ['025816 95 9', 'AMERICAN EXPRESS CO', 'CALL', 'PUT', 'COM'],
#  ['025932 AD 6', 'AMERICAN FINL GROUP INC OHIO', 'NOTE  1.486% 6/0', 'ADDED'],
#  ['025932 10 4', 'AMERICAN FINL GROUP INC OHIO', 'COM'],
#  ['025932 90 4', 'AMERICAN FINL GROUP INC OHIO'],
#  ['025932 95 4', 'AMERICAN FINL GROUP INC OHIO'],
#  ['02607P 30 5', 'AMERICAN FINL RLTY TR'],
#  ['026351 10 6', 'AMERICAN GENERAL CORP', 'CALL', 'PUT', 'COM'],
#  ['026375 AJ 4', 'AMERICAN GREETINGS CORP', 'NOTE  7.000% 7/1'],
#  ...]

# %%
def parse_list(cusip_list):
    cusip = cusip_list[0][:6] + cusip_list[0][7:9]
    name = ' '.join(cusip_list[1:3])
    name = name.split()
    name = [w for w in name if w not in {'', '*', 'DELETED', 'ADDED'}]
    name = ' '.join(name)
    return cusip, name

parse_list(cusips[-1])
# Out:
# ('98986X95', 'ZYNERBA PHARMACEUTICALS INC PUT')

# %%
m = [parse_list(li) for li in tqdm(cusips)]
m = pd.DataFrame(m, columns='cusip cusipname'.split())
m.shape
# Out:
# 100%|██████████| 889160/889160 [00:01<00:00, 512191.95it/s]
# (889160, 2)

# %%
m = m[m.cusipname.apply(lambda s: 'DELETED' not in s)]
m.shape
# Out:
# (889160, 2)

# %%
m.tail()
# Out:
#            cusip                         cusipname
# 889155  98986T90                         ZYNGA INC
# 889156  98986T95                         ZYNGA INC
# 889157  98986X10  ZYNERBA PHARMACEUTICALS INC CALL
# 889158  98986X90  ZYNERBA PHARMACEUTICALS INC CALL
# 889159  98986X95   ZYNERBA PHARMACEUTICALS INC PUT

# %%
m = m.groupby('cusip', as_index=False)['cusipname'].apply(lambda li: list(li)[-1])
m.shape
# Out:
# (36460, 2)

# %%
m[m.cusip == '00030710']
# Out:
#       cusip      cusipname
# 0  00030710  AAC HLDGS INC

# %%
m.to_csv('cusips.tsv', index=False, sep='\t')
